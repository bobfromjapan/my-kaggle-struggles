# %% [markdown]
# # CITEseq Keras Quickstart
#
# This notebook shows how to tune and cross-validate a Keras model for the CITEseq part of the *Multimodal Single-Cell Integration* competition.
#
# It does not show the EDA - see the separate notebook [MSCI EDA which makes sense ⭐️⭐️⭐️⭐️⭐️](https://www.kaggle.com/ambrosm/msci-eda-which-makes-sense).
#
# The CITEseq predictions of the Keras model are then concatenated with the Multiome predictions of @jsmithperera's [Multiome Quickstart w/ Sparse M + tSVD = 32](https://www.kaggle.com/code/jsmithperera/multiome-quickstart-w-sparse-m-tsvd-32) to a complete submission file.
#
# ## Summary
#
# The CITEseq part of the competition has sizeable datasets, when compared to the standard 16 GByte RAM of Kaggle notebooks:
# - The training input has shape 70988/*22050 (10.6 GByte).
# - The training labels have shape 70988/*140.
# - The test input has shape 48663/*22050 (4.3 GByte).
#
# Our solution strategy has five elements:
# 1. **Dimensionality reduction:** To reduce the size of the 10.6 GByte input data, we project the 22050 features to a space with only 64 dimensions by applying a truncated SVD. To these 64 dimensions, we add 144 features whose names shows their importance.
# 2. **The model:** The model is a sequential dense network with four hidden layers.
# 3. **The loss function:** The competition is scored by the average Pearson correlation coefficient between the predictions and the ground truth. As this scoring function is differentiable, we can directly use it as loss function for a neural network. This gives neural networks an advantage in comparison to algorithms which use mean squared error as a surrogate loss.
# 3. **Hyperparameter tuning with KerasTuner:** We tune the hyperparameters with [KerasTuner](https://keras.io/keras_tuner/).
# 4. **Cross-validation:** Submitting unvalidated models and relying only on the public leaderboard is bad practice. The model in this notebook is fully cross-validated with a 3-fold GroupKFold.

# %%
import os, gc, pickle, datetime, scipy.sparse
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from colorama import Fore, Back, Style

from sklearn.model_selection import GroupKFold, train_test_split, KFold
from sklearn.preprocessing import StandardScaler, scale, MinMaxScaler
from sklearn.decomposition import TruncatedSVD

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, LearningRateScheduler, EarlyStopping
from tensorflow.keras.layers import Dense, Input, Concatenate, Dropout
from tensorflow.keras.utils import plot_model
import keras_tuner

DATA_DIR = "C:/Users/Owner/Documents/dev/open-problem/open-problems-multimodal/"
FP_CELL_METADATA = os.path.join(DATA_DIR,"metadata.csv")

FP_CITE_TRAIN_INPUTS = os.path.join(DATA_DIR,"train_cite_inputs.h5")
FP_CITE_TRAIN_TARGETS = os.path.join(DATA_DIR,"train_cite_targets.h5")
FP_CITE_TEST_INPUTS = os.path.join(DATA_DIR,"test_cite_inputs.h5")

FP_MULTIOME_TRAIN_INPUTS = os.path.join(DATA_DIR,"train_multi_inputs.h5")
FP_MULTIOME_TRAIN_TARGETS = os.path.join(DATA_DIR,"train_multi_targets.h5")
FP_MULTIOME_TEST_INPUTS = os.path.join(DATA_DIR,"test_multi_inputs.h5")

FP_SUBMISSION = os.path.join(DATA_DIR,"sample_submission.csv")
FP_EVALUATION_IDS = os.path.join(DATA_DIR,"evaluation_ids.csv")

TUNE = False
SUBMIT = True
USE_SAVED_PCA = True

submission_name = "submission_svd256_wdo.csv"

# %% [markdown]
# A little trick to save time with pip: If the module is already installed (after a restart of the notebook, for instance), pip wastes 10 seconds by checking whether a newer version exists. We can skip this check by testing for the presence of the module in a simple if statement.

# %%
# %%time
# If you see a warning "Failed to establish a new connection" running this cell,
# go to "Settings" on the right hand side, 
# and turn on internet. Note, you need to be phone verified.
# We need this library to read HDF files.
# if not os.path.exists('/opt/conda/lib/python3.7/site-packages/tables'):
#     !pip install --quiet tables
# Out:
# Wall time: 0 ns

# %% [markdown]
# # The scoring function
#
# This competition has a special metric: For every row, it computes the Pearson correlation between y_true and y_pred, and then all these correlation coefficients are averaged. We implement two variants of the metric: The first one is for numpy arrays, the second one for tensors - thanks to @lucasmorin for the [original tensor implementation](https://www.kaggle.com/competitions/open-problems-multimodal/discussion/347595).

# %%
def correlation_score(y_true, y_pred):
    """Scores the predictions according to the competition rules. 
    
    It is assumed that the predictions are not constant.
    
    Returns the average of each sample's Pearson correlation coefficient"""
    if type(y_true) == pd.DataFrame: y_true = y_true.values
    if type(y_pred) == pd.DataFrame: y_pred = y_pred.values
    corrsum = 0
    for i in range(len(y_true)):
        corrsum += np.corrcoef(y_true[i], y_pred[i])[1, 0]
    return corrsum / len(y_true)

def negative_correlation_loss(y_true, y_pred):
    """Negative correlation loss function for Keras
    
    Precondition:
    y_true.mean(axis=1) == 0
    y_true.std(axis=1) == 1
    
    Returns:
    -1 = perfect positive correlation
    1 = totally negative correlation
    """
    my = K.mean(tf.convert_to_tensor(y_pred), axis=1)
    my = tf.tile(tf.expand_dims(my, axis=1), (1, y_true.shape[1]))
    ym = y_pred - my
    r_num = K.sum(tf.multiply(y_true, ym), axis=1)
    r_den = tf.sqrt(K.sum(K.square(ym), axis=1) * float(y_true.shape[-1]))
    r = tf.reduce_mean(r_num / r_den)
    return - r


class RmseObjective(object):
    def calc_ders_range(self, approxes, targets, weights):
        assert len(approxes) == len(targets)
        if weights is not None:
            assert len(weights) == len(approxes)
        
        result = []
        for index in range(len(targets)):
            der1 = targets[index] - approxes[index]
            der2 = -1

            if weights is not None:
                der1 *= weights[index]
                der2 *= weights[index]

            result.append((der1, der2))
        return result

# %% [markdown]
# # Data loading and preprocessing
#
# The metadata is used only for the `GroupKFold`:

# %%
metadata_df = pd.read_csv(FP_CELL_METADATA, index_col='cell_id')
metadata_df = metadata_df[metadata_df.technology=="citeseq"]
metadata_df.shape
# Out:
# (119651, 4)

# %%
metadata_df.head()
# Out:
#               day  donor cell_type technology
# cell_id
# c2150f55becb    2  27678       HSC    citeseq
# 65b7edf8a4da    2  27678       HSC    citeseq
# c1b26cb1057b    2  27678      EryP    citeseq
# 917168fa6f83    2  27678      NeuP    citeseq
# 2b29feeca86d    2  27678      EryP    citeseq

# %% [markdown]
# We now define two sets of features:
# - `constant_cols` is the set of all features which are constant in the train or test datset. These columns will be discarded immediately after loading.
# - `important_cols` is the set of all features whose name matches the name of a target protein. If a gene is named 'ENSG00000114013_CD86', it should be related to a protein named 'CD86'. These features will be used for the model unchanged, that is, they don't undergo dimensionality reduction.

# %%
# constant_cols = list(X.columns[(X == 0).all(axis=0).values]) + list(X_test.columns[(X_test == 0).all(axis=0).values])
constant_cols = ['ENSG00000003137_CYP26B1', 'ENSG00000004848_ARX', 'ENSG00000006606_CCL26', 'ENSG00000010379_SLC6A13', 'ENSG00000010932_FMO1', 'ENSG00000017427_IGF1', 'ENSG00000022355_GABRA1', 'ENSG00000041982_TNC', 'ENSG00000060709_RIMBP2', 'ENSG00000064886_CHI3L2', 'ENSG00000065717_TLE2', 'ENSG00000067798_NAV3', 'ENSG00000069535_MAOB', 'ENSG00000073598_FNDC8', 'ENSG00000074219_TEAD2', 'ENSG00000074964_ARHGEF10L', 'ENSG00000077264_PAK3', 'ENSG00000078053_AMPH', 'ENSG00000082684_SEMA5B', 'ENSG00000083857_FAT1', 'ENSG00000084628_NKAIN1', 'ENSG00000084734_GCKR', 'ENSG00000086967_MYBPC2', 'ENSG00000087258_GNAO1', 'ENSG00000089505_CMTM1', 'ENSG00000091129_NRCAM', 'ENSG00000091986_CCDC80', 'ENSG00000092377_TBL1Y', 'ENSG00000092969_TGFB2', 'ENSG00000095397_WHRN', 'ENSG00000095970_TREM2', 'ENSG00000099715_PCDH11Y', 'ENSG00000100197_CYP2D6', 'ENSG00000100218_RSPH14', 'ENSG00000100311_PDGFB', 'ENSG00000100362_PVALB', 'ENSG00000100373_UPK3A', 'ENSG00000100625_SIX4', 'ENSG00000100867_DHRS2', 'ENSG00000100985_MMP9', 'ENSG00000101197_BIRC7', 'ENSG00000101298_SNPH', 'ENSG00000102387_TAF7L', 'ENSG00000103034_NDRG4', 'ENSG00000104059_FAM189A1', 'ENSG00000104112_SCG3', 'ENSG00000104313_EYA1', 'ENSG00000104892_KLC3', 'ENSG00000105088_OLFM2', 'ENSG00000105261_OVOL3', 'ENSG00000105290_APLP1', 'ENSG00000105507_CABP5', 'ENSG00000105642_KCNN1', 'ENSG00000105694_ELOCP28', 'ENSG00000105707_HPN', 'ENSG00000105894_PTN', 'ENSG00000106018_VIPR2', 'ENSG00000106541_AGR2', 'ENSG00000107317_PTGDS', 'ENSG00000108688_CCL7', 'ENSG00000108702_CCL1', 'ENSG00000108947_EFNB3', 'ENSG00000109193_SULT1E1', 'ENSG00000109794_FAM149A', 'ENSG00000109832_DDX25', 'ENSG00000110195_FOLR1', 'ENSG00000110375_UPK2', 'ENSG00000110436_SLC1A2', 'ENSG00000111339_ART4', 'ENSG00000111863_ADTRP', 'ENSG00000112761_WISP3', 'ENSG00000112852_PCDHB2', 'ENSG00000114251_WNT5A', 'ENSG00000114279_FGF12', 'ENSG00000114455_HHLA2', 'ENSG00000114757_PEX5L', 'ENSG00000115155_OTOF', 'ENSG00000115266_APC2', 'ENSG00000115297_TLX2', 'ENSG00000115590_IL1R2', 'ENSG00000115844_DLX2', 'ENSG00000116194_ANGPTL1', 'ENSG00000116661_FBXO2', 'ENSG00000116774_OLFML3', 'ENSG00000117322_CR2', 'ENSG00000117971_CHRNB4', 'ENSG00000118322_ATP10B', 'ENSG00000118402_ELOVL4', 'ENSG00000118520_ARG1', 'ENSG00000118946_PCDH17', 'ENSG00000118972_FGF23', 'ENSG00000119771_KLHL29', 'ENSG00000120549_KIAA1217', 'ENSG00000121316_PLBD1', 'ENSG00000121905_HPCA', 'ENSG00000122224_LY9', 'ENSG00000124194_GDAP1L1', 'ENSG00000124440_HIF3A', 'ENSG00000124657_OR2B6', 'ENSG00000125462_C1orf61', 'ENSG00000125895_TMEM74B', 'ENSG00000126838_PZP', 'ENSG00000128422_KRT17', 'ENSG00000128918_ALDH1A2', 'ENSG00000129170_CSRP3', 'ENSG00000129214_SHBG', 'ENSG00000129673_AANAT', 'ENSG00000129910_CDH15', 'ENSG00000130294_KIF1A', 'ENSG00000130307_USHBP1', 'ENSG00000130545_CRB3', 'ENSG00000131019_ULBP3', 'ENSG00000131044_TTLL9', 'ENSG00000131183_SLC34A1', 'ENSG00000131386_GALNT15', 'ENSG00000131400_NAPSA', 'ENSG00000131914_LIN28A', 'ENSG00000131941_RHPN2', 'ENSG00000131951_LRRC9', 'ENSG00000132170_PPARG', 'ENSG00000132681_ATP1A4', 'ENSG00000132958_TPTE2', 'ENSG00000133454_MYO18B', 'ENSG00000134545_KLRC1', 'ENSG00000134853_PDGFRA', 'ENSG00000135083_CCNJL', 'ENSG00000135100_HNF1A', 'ENSG00000135116_HRK', 'ENSG00000135312_HTR1B', 'ENSG00000135324_MRAP2', 'ENSG00000135436_FAM186B', 'ENSG00000135472_FAIM2', 'ENSG00000135898_GPR55', 'ENSG00000135929_CYP27A1', 'ENSG00000136002_ARHGEF4', 'ENSG00000136099_PCDH8', 'ENSG00000136274_NACAD', 'ENSG00000137078_SIT1', 'ENSG00000137142_IGFBPL1', 'ENSG00000137473_TTC29', 'ENSG00000137474_MYO7A', 'ENSG00000137491_SLCO2B1', 'ENSG00000137691_CFAP300', 'ENSG00000137731_FXYD2', 'ENSG00000137747_TMPRSS13', 'ENSG00000137878_GCOM1', 'ENSG00000138411_HECW2', 'ENSG00000138741_TRPC3', 'ENSG00000138769_CDKL2', 'ENSG00000138823_MTTP', 'ENSG00000139908_TSSK4', 'ENSG00000140832_MARVELD3', 'ENSG00000142178_SIK1', 'ENSG00000142538_PTH2', 'ENSG00000142910_TINAGL1', 'ENSG00000143217_NECTIN4', 'ENSG00000143858_SYT2', 'ENSG00000144130_NT5DC4', 'ENSG00000144214_LYG1', 'ENSG00000144290_SLC4A10', 'ENSG00000144366_GULP1', 'ENSG00000144583_MARCH4', 'ENSG00000144771_LRTM1', 'ENSG00000144891_AGTR1', 'ENSG00000145087_STXBP5L', 'ENSG00000145107_TM4SF19', 'ENSG00000146197_SCUBE3', 'ENSG00000146966_DENND2A', 'ENSG00000147082_CCNB3', 'ENSG00000147614_ATP6V0D2', 'ENSG00000147642_SYBU', 'ENSG00000147869_CER1', 'ENSG00000149403_GRIK4', 'ENSG00000149596_JPH2', 'ENSG00000150630_VEGFC', 'ENSG00000150722_PPP1R1C', 'ENSG00000151631_AKR1C6P', 'ENSG00000151704_KCNJ1', 'ENSG00000152154_TMEM178A', 'ENSG00000152292_SH2D6', 'ENSG00000152315_KCNK13', 'ENSG00000152503_TRIM36', 'ENSG00000153253_SCN3A', 'ENSG00000153902_LGI4', 'ENSG00000153930_ANKFN1', 'ENSG00000154040_CABYR', 'ENSG00000154118_JPH3', 'ENSG00000154175_ABI3BP', 'ENSG00000154645_CHODL', 'ENSG00000157060_SHCBP1L', 'ENSG00000157087_ATP2B2', 'ENSG00000157152_SYN2', 'ENSG00000157168_NRG1', 'ENSG00000157680_DGKI', 'ENSG00000158246_TENT5B', 'ENSG00000158477_CD1A', 'ENSG00000158481_CD1C', 'ENSG00000158488_CD1E', 'ENSG00000159189_C1QC', 'ENSG00000159217_IGF2BP1', 'ENSG00000160683_CXCR5', 'ENSG00000160801_PTH1R', 'ENSG00000160973_FOXH1', 'ENSG00000161594_KLHL10', 'ENSG00000162409_PRKAA2', 'ENSG00000162840_MT2P1', 'ENSG00000162873_KLHDC8A', 'ENSG00000162944_RFTN2', 'ENSG00000162949_CAPN13', 'ENSG00000163116_STPG2', 'ENSG00000163288_GABRB1', 'ENSG00000163531_NFASC', 'ENSG00000163618_CADPS', 'ENSG00000163637_PRICKLE2', 'ENSG00000163735_CXCL5', 'ENSG00000163873_GRIK3', 'ENSG00000163898_LIPH', 'ENSG00000164061_BSN', 'ENSG00000164078_MST1R', 'ENSG00000164123_C4orf45', 'ENSG00000164690_SHH', 'ENSG00000164761_TNFRSF11B', 'ENSG00000164821_DEFA4', 'ENSG00000164845_FAM86FP', 'ENSG00000164867_NOS3', 'ENSG00000166073_GPR176', 'ENSG00000166148_AVPR1A', 'ENSG00000166250_CLMP', 'ENSG00000166257_SCN3B', 'ENSG00000166268_MYRFL', 'ENSG00000166523_CLEC4E', 'ENSG00000166535_A2ML1', 'ENSG00000166819_PLIN1', 'ENSG00000166928_MS4A14', 'ENSG00000167210_LOXHD1', 'ENSG00000167306_MYO5B', 'ENSG00000167634_NLRP7', 'ENSG00000167748_KLK1', 'ENSG00000167889_MGAT5B', 'ENSG00000168140_VASN', 'ENSG00000168546_GFRA2', 'ENSG00000168646_AXIN2', 'ENSG00000168955_TM4SF20', 'ENSG00000168993_CPLX1', 'ENSG00000169075_Z99496.1', 'ENSG00000169194_IL13', 'ENSG00000169246_NPIPB3', 'ENSG00000169884_WNT10B', 'ENSG00000169900_PYDC1', 'ENSG00000170074_FAM153A', 'ENSG00000170075_GPR37L1', 'ENSG00000170289_CNGB3', 'ENSG00000170356_OR2A20P', 'ENSG00000170537_TMC7', 'ENSG00000170689_HOXB9', 'ENSG00000170827_CELP', 'ENSG00000171346_KRT15', 'ENSG00000171368_TPPP', 'ENSG00000171501_OR1N2', 'ENSG00000171532_NEUROD2', 'ENSG00000171611_PTCRA', 'ENSG00000171873_ADRA1D', 'ENSG00000171916_LGALS9C', 'ENSG00000172005_MAL', 'ENSG00000172987_HPSE2', 'ENSG00000173068_BNC2', 'ENSG00000173077_DEC1', 'ENSG00000173210_ABLIM3', 'ENSG00000173267_SNCG', 'ENSG00000173369_C1QB', 'ENSG00000173372_C1QA', 'ENSG00000173391_OLR1', 'ENSG00000173626_TRAPPC3L', 'ENSG00000173698_ADGRG2', 'ENSG00000173868_PHOSPHO1', 'ENSG00000174407_MIR1-1HG', 'ENSG00000174807_CD248', 'ENSG00000175206_NPPA', 'ENSG00000175746_C15orf54', 'ENSG00000175985_PLEKHD1', 'ENSG00000176043_AC007160.1', 'ENSG00000176399_DMRTA1', 'ENSG00000176510_OR10AC1', 'ENSG00000176697_BDNF', 'ENSG00000176826_FKBP9P1', 'ENSG00000176988_FMR1NB', 'ENSG00000177324_BEND2', 'ENSG00000177335_C8orf31', 'ENSG00000177535_OR2B11', 'ENSG00000177614_PGBD5', 'ENSG00000177707_NECTIN3', 'ENSG00000178033_CALHM5', 'ENSG00000178175_ZNF366', 'ENSG00000178462_TUBAL3', 'ENSG00000178732_GP5', 'ENSG00000178750_STX19', 'ENSG00000179058_C9orf50', 'ENSG00000179101_AL590139.1', 'ENSG00000179388_EGR3', 'ENSG00000179611_DGKZP1', 'ENSG00000179899_PHC1P1', 'ENSG00000179934_CCR8', 'ENSG00000180537_RNF182', 'ENSG00000180712_LINC02363', 'ENSG00000180988_OR52N2', 'ENSG00000181001_OR52N1', 'ENSG00000181616_OR52H1', 'ENSG00000181634_TNFSF15', 'ENSG00000182021_AL591379.1', 'ENSG00000182230_FAM153B', 'ENSG00000182853_VMO1', 'ENSG00000183090_FREM3', 'ENSG00000183562_AC131971.1', 'ENSG00000183615_FAM167B', 'ENSG00000183625_CCR3', 'ENSG00000183770_FOXL2', 'ENSG00000183779_ZNF703', 'ENSG00000183831_ANKRD45', 'ENSG00000183844_FAM3B', 'ENSG00000183960_KCNH8', 'ENSG00000184106_TREML3P', 'ENSG00000184227_ACOT1', 'ENSG00000184363_PKP3', 'ENSG00000184434_LRRC19', 'ENSG00000184454_NCMAP', 'ENSG00000184571_PIWIL3', 'ENSG00000184702_SEPT5', 'ENSG00000184908_CLCNKB', 'ENSG00000184923_NUTM2A', 'ENSG00000185070_FLRT2', 'ENSG00000185156_MFSD6L', 'ENSG00000185567_AHNAK2', 'ENSG00000185686_PRAME', 'ENSG00000186190_BPIFB3', 'ENSG00000186191_BPIFB4', 'ENSG00000186231_KLHL32', 'ENSG00000186431_FCAR', 'ENSG00000186715_MST1L', 'ENSG00000187116_LILRA5', 'ENSG00000187185_AC092118.1', 'ENSG00000187268_FAM9C', 'ENSG00000187554_TLR5', 'ENSG00000187867_PALM3', 'ENSG00000188153_COL4A5', 'ENSG00000188158_NHS', 'ENSG00000188163_FAM166A', 'ENSG00000188316_ENO4', 'ENSG00000188959_C9orf152', 'ENSG00000189013_KIR2DL4', 'ENSG00000189409_MMP23B', 'ENSG00000196092_PAX5', 'ENSG00000196260_SFTA2', 'ENSG00000197358_BNIP3P1', 'ENSG00000197446_CYP2F1', 'ENSG00000197540_GZMM', 'ENSG00000198049_AVPR1B', 'ENSG00000198134_AC007537.1', 'ENSG00000198156_NPIPB6', 'ENSG00000198221_AFDN-DT', 'ENSG00000198626_RYR2', 'ENSG00000198759_EGFL6', 'ENSG00000198822_GRM3', 'ENSG00000198963_RORB', 'ENSG00000199090_MIR326', 'ENSG00000199753_SNORD104', 'ENSG00000199787_RF00406', 'ENSG00000199872_RNU6-942P', 'ENSG00000200075_RF00402', 'ENSG00000200296_RNU1-83P', 'ENSG00000200683_RNU6-379P', 'ENSG00000201044_RNU6-268P', 'ENSG00000201343_RF00019', 'ENSG00000201564_RN7SKP50', 'ENSG00000201616_RNU1-91P', 'ENSG00000201737_RNU1-133P', 'ENSG00000202048_SNORD114-20', 'ENSG00000202415_RN7SKP269', 'ENSG00000203395_AC015969.1', 'ENSG00000203721_LINC00862', 'ENSG00000203727_SAMD5', 'ENSG00000203737_GPR52', 'ENSG00000203783_PRR9', 'ENSG00000203867_RBM20', 'ENSG00000203907_OOEP', 'ENSG00000203999_LINC01270', 'ENSG00000204010_IFIT1B', 'ENSG00000204044_SLC12A5-AS1', 'ENSG00000204091_TDRG1', 'ENSG00000204121_ECEL1P1', 'ENSG00000204165_CXorf65', 'ENSG00000204173_LRRC37A5P', 'ENSG00000204248_COL11A2', 'ENSG00000204424_LY6G6F', 'ENSG00000204539_CDSN', 'ENSG00000204583_LRCOL1', 'ENSG00000204677_FAM153C', 'ENSG00000204709_LINC01556', 'ENSG00000204711_C9orf135', 'ENSG00000204792_LINC01291', 'ENSG00000204850_AC011484.1', 'ENSG00000204851_PNMA8B', 'ENSG00000204909_SPINK9', 'ENSG00000205037_AC134312.1', 'ENSG00000205038_PKHD1L1', 'ENSG00000205089_CCNI2', 'ENSG00000205106_DKFZp779M0652', 'ENSG00000205364_MT1M', 'ENSG00000205502_C2CD4B', 'ENSG00000205746_AC126755.1', 'ENSG00000205856_C22orf42', 'ENSG00000206052_DOK6', 'ENSG00000206579_XKR4', 'ENSG00000206645_RF00019', 'ENSG00000206786_RNU6-701P', 'ENSG00000206846_RF00019', 'ENSG00000206848_RNU6-890P', 'ENSG00000207088_SNORA7B', 'ENSG00000207181_SNORA14B', 'ENSG00000207234_RNU6-125P', 'ENSG00000207326_RF00019', 'ENSG00000207359_RNU6-925P', 'ENSG00000211677_IGLC2', 'ENSG00000211699_TRGV3', 'ENSG00000211895_IGHA1', 'ENSG00000212385_RNU6-817P', 'ENSG00000212391_RF00554', 'ENSG00000212607_SNORA3B', 'ENSG00000212829_RPS26P3', 'ENSG00000213083_AC010731.1', 'ENSG00000213216_AC007066.1', 'ENSG00000213222_AC093724.1', 'ENSG00000213228_RPL12P38', 'ENSG00000213250_RBMS2P1', 'ENSG00000213272_RPL7AP9', 'ENSG00000213303_AC008481.1', 'ENSG00000213402_PTPRCAP', 'ENSG00000213471_TTLL13P', 'ENSG00000213588_ZBTB9', 'ENSG00000213609_RPL7AP50', 'ENSG00000213757_AC020898.1', 'ENSG00000213931_HBE1', 'ENSG00000213950_RPS10P2', 'ENSG00000213994_AL157395.1', 'ENSG00000214787_MS4A4E', 'ENSG00000214866_DCDC2C', 'ENSG00000214908_AL353678.1', 'ENSG00000214975_PPIAP29', 'ENSG00000215198_AL353795.1', 'ENSG00000215208_KRT18P60', 'ENSG00000215218_UBE2QL1', 'ENSG00000215297_AL354941.1', 'ENSG00000215464_AP000354.1', 'ENSG00000215483_LINC00598', 'ENSG00000215817_ZC3H11B', 'ENSG00000215861_AC245297.1', 'ENSG00000215910_C1orf167', 'ENSG00000216475_AL024474.1', 'ENSG00000217195_AL513475.1', 'ENSG00000217414_DDX18P3', 'ENSG00000217512_AL356776.1', 'ENSG00000218351_RPS3AP23', 'ENSG00000218418_AL591135.1', 'ENSG00000218749_AL033519.1', 'ENSG00000218766_AL450338.1', 'ENSG00000218792_HSPD1P16', 'ENSG00000219249_AMZ2P2', 'ENSG00000219395_HSPA8P15', 'ENSG00000219410_AC125494.1', 'ENSG00000219932_RPL12P8', 'ENSG00000220091_LAP3P1', 'ENSG00000220237_RPS24P12', 'ENSG00000220494_YAP1P1', 'ENSG00000221102_SNORA11B', 'ENSG00000221887_HMSD', 'ENSG00000222276_RNU2-33P', 'ENSG00000222370_SNORA36B', 'ENSG00000222421_RF00019', 'ENSG00000222431_RNU6-141P', 'ENSG00000223342_AL158817.1', 'ENSG00000223379_AL391987.3', 'ENSG00000223403_MEG9', 'ENSG00000223519_KIF28P', 'ENSG00000223576_AL355001.1', 'ENSG00000223668_EEF1A1P24', 'ENSG00000223741_PSMD4P1', 'ENSG00000223779_AC239800.1', 'ENSG00000223783_LINC01983', 'ENSG00000223784_LINP1', 'ENSG00000223855_HRAT92', 'ENSG00000223884_AC068481.1', 'ENSG00000223899_SEC13P1', 'ENSG00000224067_AL354877.1', 'ENSG00000224072_AL139811.1', 'ENSG00000224081_SLC44A3-AS1', 'ENSG00000224099_AC104823.1', 'ENSG00000224116_INHBA-AS1', 'ENSG00000224137_LINC01857', 'ENSG00000224155_AC073136.2', 'ENSG00000224321_RPL12P14', 'ENSG00000224402_OR6D1P', 'ENSG00000224479_AC104162.1', 'ENSG00000224599_BMS1P12', 'ENSG00000224689_ZNF812P', 'ENSG00000224848_AL589843.1', 'ENSG00000224908_TIMM8BP2', 'ENSG00000224957_LINC01266', 'ENSG00000224959_AC017002.1', 'ENSG00000224988_AL158207.1', 'ENSG00000224993_RPL29P12', 'ENSG00000225096_AL445250.1', 'ENSG00000225101_OR52K3P', 'ENSG00000225107_AC092484.1', 'ENSG00000225187_AC073283.1', 'ENSG00000225313_AL513327.1', 'ENSG00000225345_SNX18P3', 'ENSG00000225393_BX571846.1', 'ENSG00000225422_RBMS1P1', 'ENSG00000225423_TNPO1P1', 'ENSG00000225531_AL807761.2', 'ENSG00000225554_AL359764.1', 'ENSG00000225650_EIF2S2P5', 'ENSG00000225674_IPO7P2', 'ENSG00000225807_AC069281.1', 'ENSG00000226010_AL355852.1', 'ENSG00000226084_AC113935.1', 'ENSG00000226251_AL451060.1', 'ENSG00000226383_LINC01876', 'ENSG00000226491_FTOP1', 'ENSG00000226501_USF1P1', 'ENSG00000226545_AL357552.1', 'ENSG00000226564_FTH1P20', 'ENSG00000226617_RPL21P110', 'ENSG00000226647_AL365356.1', 'ENSG00000226800_CACTIN-AS1', 'ENSG00000226913_BSN-DT', 'ENSG00000226948_RPS4XP2', 'ENSG00000226970_AL450063.1', 'ENSG00000227006_AL136988.2', 'ENSG00000227051_C14orf132', 'ENSG00000227072_AL353706.1', 'ENSG00000227110_LMCD1-AS1', 'ENSG00000227192_AL023581.2', 'ENSG00000227198_C6orf47-AS1', 'ENSG00000227207_RPL31P12', 'ENSG00000227477_STK4-AS1', 'ENSG00000227541_SFR1P1', 'ENSG00000227590_ATP5MC1P5', 'ENSG00000227649_MTND6P32', 'ENSG00000227682_ATP5F1AP2', 'ENSG00000227740_AL513329.1', 'ENSG00000227742_CALR4P', 'ENSG00000228097_MTATP6P11', 'ENSG00000228140_AL031283.1', 'ENSG00000228175_GEMIN8P4', 'ENSG00000228212_OFD1P17', 'ENSG00000228232_GAPDHP1', 'ENSG00000228317_AL158070.1', 'ENSG00000228413_AC024937.1', 'ENSG00000228430_AL162726.3', 'ENSG00000228501_RPL15P18', 'ENSG00000228550_AC073583.1', 'ENSG00000228655_AC096558.1', 'ENSG00000228727_SAPCD1', 'ENSG00000228826_AL592494.1', 'ENSG00000228839_PIK3IP1-AS1', 'ENSG00000228863_AL121985.1', 'ENSG00000229066_AC093459.1', 'ENSG00000229150_CRYGEP', 'ENSG00000229154_KCNQ5-AS1', 'ENSG00000229163_NAP1L1P2', 'ENSG00000229236_TTTY10', 'ENSG00000229274_AL662860.1', 'ENSG00000229308_AC010737.1', 'ENSG00000229326_AC069154.1', 'ENSG00000229372_SZT2-AS1', 'ENSG00000229444_AL451062.1', 'ENSG00000229567_AL139421.1', 'ENSG00000229703_CR589904.1', 'ENSG00000229742_AC092809.1', 'ENSG00000229758_DYNLT3P2', 'ENSG00000229839_AC018462.1', 'ENSG00000229847_EMX2OS', 'ENSG00000229853_AL034418.1', 'ENSG00000229918_DOCK9-AS1', 'ENSG00000229953_AL590666.2', 'ENSG00000229992_HMGB3P9', 'ENSG00000230063_AL360091.2', 'ENSG00000230064_AL772161.1', 'ENSG00000230138_AC119428.2', 'ENSG00000230149_AL021707.3', 'ENSG00000230289_AL358781.2', 'ENSG00000230295_GTF2IP23', 'ENSG00000230479_AP000695.1', 'ENSG00000230508_RPL19P21', 'ENSG00000230519_HMGB1P49', 'ENSG00000230534_AL392046.1', 'ENSG00000230563_AL121757.1', 'ENSG00000230721_AL049597.1', 'ENSG00000230772_VN1R108P', 'ENSG00000230777_RPS29P5', 'ENSG00000230799_AC007279.1', 'ENSG00000230813_AL356583.3', 'ENSG00000230815_AL807757.1', 'ENSG00000230872_MFSD13B', 'ENSG00000230910_AL391807.1', 'ENSG00000230912_AL021707.4', 'ENSG00000230968_AC084149.2', 'ENSG00000230993_RPL12P15', 'ENSG00000231265_TRERNA1', 'ENSG00000231307_RPS3P2', 'ENSG00000231407_AL354732.1', 'ENSG00000231449_AC097359.1', 'ENSG00000231507_LINC01353', 'ENSG00000231531_HINT1P1', 'ENSG00000231548_OR55B1P', 'ENSG00000231731_AC010976.1', 'ENSG00000231742_LINC01273', 'ENSG00000231788_RPL31P50', 'ENSG00000231830_AC245140.1', 'ENSG00000231927_AC093734.1', 'ENSG00000231993_EP300-AS1', 'ENSG00000232027_AL671986.1', 'ENSG00000232028_AC007391.1', 'ENSG00000232065_LINC01063', 'ENSG00000232133_IMPDH1P10', 'ENSG00000232139_LINC00867', 'ENSG00000232273_FTH1P1', 'ENSG00000232333_RPS27AP2', 'ENSG00000232466_AL356133.1', 'ENSG00000232500_AP005273.1', 'ENSG00000232530_LIF-AS1', 'ENSG00000232568_RPL23AP35', 'ENSG00000232578_AC093311.1', 'ENSG00000232606_LINC01412', 'ENSG00000232654_FAM136BP', 'ENSG00000232656_IDI2-AS1', 'ENSG00000232719_AC007272.1', 'ENSG00000232803_SLCO4A1-AS1', 'ENSG00000232987_LINC01219', 'ENSG00000233025_CRYZP1', 'ENSG00000233093_LINC00892', 'ENSG00000233099_AC095030.1', 'ENSG00000233401_PRKAR1AP1', 'ENSG00000233427_AL009181.1', 'ENSG00000233540_DNM3-IT1', 'ENSG00000233674_AL451062.2', 'ENSG00000233825_AL391839.2', 'ENSG00000233862_AC016907.2', 'ENSG00000233994_GDI2P2', 'ENSG00000234026_AL157834.2', 'ENSG00000234106_SRP14P2', 'ENSG00000234145_NAP1L4P3', 'ENSG00000234174_AC016683.1', 'ENSG00000234271_Z98752.2', 'ENSG00000234425_AL138930.1', 'ENSG00000234488_AC096664.2', 'ENSG00000234630_AC245060.2', 'ENSG00000234645_YWHAEP5', 'ENSG00000234718_AC007161.1', 'ENSG00000234810_AL603840.1', 'ENSG00000235045_RPL7P8', 'ENSG00000235072_AC012074.1', 'ENSG00000235214_FAM83C-AS1', 'ENSG00000235288_AC099329.1', 'ENSG00000235376_RPEL1', 'ENSG00000235429_AC083875.1', 'ENSG00000235472_EIF4A1P7', 'ENSG00000235478_LINC01664', 'ENSG00000235531_MSC-AS1', 'ENSG00000235640_AC092646.2', 'ENSG00000235677_NPM1P26', 'ENSG00000235683_AC018442.1', 'ENSG00000235701_PCBP2P1', 'ENSG00000235740_PHACTR2-AS1', 'ENSG00000235774_AC023347.1', 'ENSG00000235802_HCFC1-AS1', 'ENSG00000235917_MTCO2P11', 'ENSG00000235958_UBOX5-AS1', 'ENSG00000236032_OR5H14', 'ENSG00000236180_AL445669.2', 'ENSG00000236254_MTND4P14', 'ENSG00000236283_AC019197.1', 'ENSG00000236290_EEF1GP7', 'ENSG00000236317_AC104333.2', 'ENSG00000236364_AL358115.1', 'ENSG00000236457_AC090617.1', 'ENSG00000236564_YWHAQP5', 'ENSG00000236671_PRKG1-AS1', 'ENSG00000236680_AL356000.1', 'ENSG00000236682_AC068282.1', 'ENSG00000236711_SMAD9-IT1', 'ENSG00000236806_RPL7AP15', 'ENSG00000236869_ZKSCAN7-AS1', 'ENSG00000236886_AC007563.2', 'ENSG00000236915_AL356270.1', 'ENSG00000236936_AL031005.1', 'ENSG00000237057_LINC02087', 'ENSG00000237101_AC092809.4', 'ENSG00000237276_ANO7L1', 'ENSG00000237317_AL022400.1', 'ENSG00000237387_AL022329.2', 'ENSG00000237618_BTBD7P2', 'ENSG00000237685_AL139039.3', 'ENSG00000237757_EEF1A1P30', 'ENSG00000237766_GGTA2P', 'ENSG00000237798_AC010894.4', 'ENSG00000238015_AC104837.2', 'ENSG00000238133_MAP3K20-AS1', 'ENSG00000238259_AC067940.1', 'ENSG00000238324_RN7SKP198', 'ENSG00000238358_AC004969.1', 'ENSG00000239219_AC008040.1', 'ENSG00000239316_RN7SL11P', 'ENSG00000239474_KLHL41', 'ENSG00000239527_RPS23P7', 'ENSG00000239642_MEIKIN', 'ENSG00000239650_GUSBP4', 'ENSG00000239686_AL158801.1', 'ENSG00000239701_AC006512.1', 'ENSG00000239705_AL354710.2', 'ENSG00000239797_RPL21P39', 'ENSG00000239830_RPS4XP22', 'ENSG00000239930_AP001625.3', 'ENSG00000240086_AC092969.1', 'ENSG00000240087_RPSAP12', 'ENSG00000240183_RN7SL297P', 'ENSG00000240219_AL512306.2', 'ENSG00000240498_CDKN2B-AS1', 'ENSG00000240809_AC026877.1', 'ENSG00000240993_RN7SL459P', 'ENSG00000241111_PRICKLE2-AS1', 'ENSG00000241135_LINC00881', 'ENSG00000241319_SETP6', 'ENSG00000241570_PAQR9-AS1', 'ENSG00000241631_RN7SL316P', 'ENSG00000241932_AC092324.1', 'ENSG00000241933_DENND6A-DT', 'ENSG00000242060_RPS3AP49', 'ENSG00000242107_LINC01100', 'ENSG00000242175_RN7SL127P', 'ENSG00000242431_AC107398.1', 'ENSG00000242551_POU5F1P6', 'ENSG00000242571_RPL21P11', 'ENSG00000242641_LINC00971', 'ENSG00000242747_AC090515.1', 'ENSG00000242992_FTH1P4', 'ENSG00000243055_GK-AS1', 'ENSG00000243498_UBA52P5', 'ENSG00000243592_RPL17P22', 'ENSG00000243709_LEFTY1', 'ENSG00000243830_AC092865.1', 'ENSG00000243836_WDR86-AS1', 'ENSG00000243961_PARAL1', 'ENSG00000244021_AC093591.1', 'ENSG00000244097_RPS4XP17', 'ENSG00000244151_AC010973.2', 'ENSG00000244183_PPIAP71', 'ENSG00000244242_IFITM10', 'ENSG00000244245_AC133134.1', 'ENSG00000244251_AC013356.1', 'ENSG00000244355_LY6G6D', 'ENSG00000244357_RN7SL145P', 'ENSG00000244476_ERVFRD-1', 'ENSG00000244482_LILRA6', 'ENSG00000244585_RPL12P33', 'ENSG00000244618_RN7SL334P', 'ENSG00000244703_CD46P1', 'ENSG00000245261_AL133375.1', 'ENSG00000245482_AC046130.1', 'ENSG00000246363_LINC02458', 'ENSG00000246863_AC012377.1', 'ENSG00000247199_AC091948.1', 'ENSG00000248121_SMURF2P1', 'ENSG00000248155_CR545473.1', 'ENSG00000248223_AC026785.2', 'ENSG00000248485_PCP4L1', 'ENSG00000248690_HAS2-AS1', 'ENSG00000248884_AC010280.2', 'ENSG00000248936_AC027607.1', 'ENSG00000249140_PRDX2P3', 'ENSG00000249363_AC011411.1', 'ENSG00000249381_LINC00500', 'ENSG00000249456_AL731577.2', 'ENSG00000249492_AC114956.3', 'ENSG00000249574_AC226118.1', 'ENSG00000249614_LINC02503', 'ENSG00000249691_AC026117.1', 'ENSG00000249695_AC026369.1', 'ENSG00000249803_AC112178.1', 'ENSG00000249825_CTD-2201I18.1', 'ENSG00000249848_AC112673.1', 'ENSG00000249850_KRT18P31', 'ENSG00000249884_RNF103-CHMP3', 'ENSG00000249978_TRGV7', 'ENSG00000250130_AC090519.1', 'ENSG00000250148_KRT8P31', 'ENSG00000250332_AC010460.3', 'ENSG00000250334_LINC00989', 'ENSG00000250539_KRT8P33', 'ENSG00000250548_LINC01303', 'ENSG00000250608_AC010210.1', 'ENSG00000250635_CXXC5-AS1', 'ENSG00000250645_AC010442.2', 'ENSG00000250733_C8orf17', 'ENSG00000250853_RNF138P1', 'ENSG00000250902_SMAD1-AS1', 'ENSG00000250950_AC093752.2', 'ENSG00000250982_GAPDHP35', 'ENSG00000251129_LINC02506', 'ENSG00000251152_AC025539.1', 'ENSG00000251250_AC091951.3', 'ENSG00000251288_AC018797.3', 'ENSG00000251468_AC135352.1', 'ENSG00000251537_AC005324.3', 'ENSG00000251538_LINC02201', 'ENSG00000251584_AC096751.2', 'ENSG00000251676_SNHG27', 'ENSG00000251916_RNU1-61P', 'ENSG00000252759_RF00019', 'ENSG00000253256_AC134043.1', 'ENSG00000253305_PCDHGB6', 'ENSG00000253394_LINC00534', 'ENSG00000253490_LINC02099', 'ENSG00000253537_PCDHGA7', 'ENSG00000253629_AP000426.1', 'ENSG00000253651_SOD1P3', 'ENSG00000253730_AC015909.2', 'ENSG00000253734_LINC01289', 'ENSG00000253767_PCDHGA8', 'ENSG00000253853_AC246817.1', 'ENSG00000253873_PCDHGA11', 'ENSG00000254028_AC083843.1', 'ENSG00000254048_AC105150.1', 'ENSG00000254054_AC087273.2', 'ENSG00000254122_PCDHGB7', 'ENSG00000254248_AC068189.1', 'ENSG00000254680_AC079329.1', 'ENSG00000254708_AL139174.1', 'ENSG00000254780_AC023232.1', 'ENSG00000254810_AP001189.3', 'ENSG00000254812_AC067930.3', 'ENSG00000254842_LINC02551', 'ENSG00000254846_AL355075.1', 'ENSG00000254862_AC100771.2', 'ENSG00000254897_AP003035.1', 'ENSG00000255002_LINC02324', 'ENSG00000255074_AC018523.1', 'ENSG00000255102_AP005436.1', 'ENSG00000255156_RNY1P9', 'ENSG00000255158_AC131934.1', 'ENSG00000255222_SETP17', 'ENSG00000255256_AL136146.2', 'ENSG00000255367_AC127526.2', 'ENSG00000255418_AC090092.1', 'ENSG00000255443_CD44-AS1', 'ENSG00000255446_AP003064.2', 'ENSG00000255479_AP001189.6', 'ENSG00000255487_AC087362.2', 'ENSG00000255867_DENND5B-AS1', 'ENSG00000255871_AC007529.1', 'ENSG00000256029_SNHG28', 'ENSG00000256571_AC079866.2', 'ENSG00000256588_AC027544.2', 'ENSG00000256712_AC134349.1', 'ENSG00000256746_AC018410.1', 'ENSG00000256813_AP000777.3', 'ENSG00000256967_AC018653.3', 'ENSG00000256968_SNRPEP2', 'ENSG00000257074_RPL29P33', 'ENSG00000257120_AL356756.1', 'ENSG00000257146_AC079905.2', 'ENSG00000257195_HNRNPA1P50', 'ENSG00000257327_AC012555.1', 'ENSG00000257345_LINC02413', 'ENSG00000257379_AC023509.1', 'ENSG00000257386_AC025257.1', 'ENSG00000257431_AC089998.1', 'ENSG00000257715_AC007298.1', 'ENSG00000257838_OTOAP1', 'ENSG00000257987_TEX49', 'ENSG00000258084_AC128707.1', 'ENSG00000258090_AC093014.1', 'ENSG00000258177_AC008149.1', 'ENSG00000258357_AC023161.2', 'ENSG00000258410_AC087386.1', 'ENSG00000258498_DIO3OS', 'ENSG00000258504_AL157871.1', 'ENSG00000258512_LINC00239', 'ENSG00000258867_LINC01146', 'ENSG00000258886_HIGD1AP17', 'ENSG00000259032_ENSAP2', 'ENSG00000259100_AL157791.1', 'ENSG00000259294_AC005096.1', 'ENSG00000259327_AC023906.3', 'ENSG00000259345_AC013652.1', 'ENSG00000259377_AC026770.1', 'ENSG00000259380_AC087473.1', 'ENSG00000259442_AC105339.3', 'ENSG00000259461_ANP32BP3', 'ENSG00000259556_AC090971.3', 'ENSG00000259569_AC013489.2', 'ENSG00000259617_AC020661.3', 'ENSG00000259684_AC084756.1', 'ENSG00000259719_LINC02284', 'ENSG00000259954_IL21R-AS1', 'ENSG00000259986_AC103876.1', 'ENSG00000260135_MMP2-AS1', 'ENSG00000260206_AC105020.2', 'ENSG00000260235_AC105020.3', 'ENSG00000260269_AC105036.3', 'ENSG00000260394_Z92544.1', 'ENSG00000260425_AL031709.1', 'ENSG00000260447_AC009065.3', 'ENSG00000260615_RPL23AP97', 'ENSG00000260871_AC093510.2', 'ENSG00000260877_AP005233.2', 'ENSG00000260979_AC022167.3', 'ENSG00000261051_AC107021.2', 'ENSG00000261113_AC009034.1', 'ENSG00000261168_AL592424.1', 'ENSG00000261253_AC137932.2', 'ENSG00000261269_AC093278.2', 'ENSG00000261552_AC109460.4', 'ENSG00000261572_AC097639.1', 'ENSG00000261602_AC092115.2', 'ENSG00000261630_AC007496.2', 'ENSG00000261644_AC007728.2', 'ENSG00000261734_AC116096.1', 'ENSG00000261773_AC244090.2', 'ENSG00000261837_AC046158.2', 'ENSG00000261838_AC092718.6', 'ENSG00000261888_AC144831.1', 'ENSG00000262061_AC129507.1', 'ENSG00000262097_LINC02185', 'ENSG00000262372_CR936218.1', 'ENSG00000262406_MMP12', 'ENSG00000262580_AC087741.1', 'ENSG00000262772_LINC01977', 'ENSG00000262833_AC016245.1', 'ENSG00000263006_ROCK1P1', 'ENSG00000263011_AC108134.4', 'ENSG00000263155_MYZAP', 'ENSG00000263393_AC011825.2', 'ENSG00000263426_RN7SL471P', 'ENSG00000263503_MAPK8IP1P2', 'ENSG00000263595_RN7SL823P', 'ENSG00000263878_DLGAP1-AS4', 'ENSG00000263940_RN7SL275P', 'ENSG00000264019_AC018521.2', 'ENSG00000264031_ABHD15-AS1', 'ENSG00000264044_AC005726.2', 'ENSG00000264070_DND1P1', 'ENSG00000264188_AC106037.1', 'ENSG00000264269_AC016866.1', 'ENSG00000264339_AP001020.1', 'ENSG00000264434_AC110603.1', 'ENSG00000264714_KIAA0895LP1', 'ENSG00000265010_AC087301.1', 'ENSG00000265073_AC010761.2', 'ENSG00000265107_GJA5', 'ENSG00000265179_AP000894.2', 'ENSG00000265218_AC103810.2', 'ENSG00000265334_AC130324.2', 'ENSG00000265439_RN7SL811P', 'ENSG00000265531_FCGR1CP', 'ENSG00000265845_AC024267.4', 'ENSG00000265907_AP000919.2', 'ENSG00000265942_RN7SL577P', 'ENSG00000266256_LINC00683', 'ENSG00000266456_AP001178.3', 'ENSG00000266733_TBC1D29', 'ENSG00000266835_GAPLINC', 'ENSG00000266844_AC093330.1', 'ENSG00000266903_AC243964.2', 'ENSG00000266944_AC005262.1', 'ENSG00000266946_MRPL37P1', 'ENSG00000266947_AC022916.1', 'ENSG00000267034_AC010980.2', 'ENSG00000267044_AC005757.1', 'ENSG00000267147_LINC01842', 'ENSG00000267175_AC105094.2', 'ENSG00000267191_AC006213.3', 'ENSG00000267275_AC020911.2', 'ENSG00000267288_AC138150.2', 'ENSG00000267313_KC6', 'ENSG00000267316_AC090409.2', 'ENSG00000267323_SLC25A1P5', 'ENSG00000267345_AC010632.1', 'ENSG00000267387_AC020931.1', 'ENSG00000267395_DM1-AS', 'ENSG00000267429_AC006116.6', 'ENSG00000267452_LINC02073', 'ENSG00000267491_AC100788.1', 'ENSG00000267529_AP005131.4', 'ENSG00000267554_AC015911.8', 'ENSG00000267601_AC022966.1', 'ENSG00000267638_AC023855.1', 'ENSG00000267665_AC021683.3', 'ENSG00000267681_AC135721.1', 'ENSG00000267703_AC020917.2', 'ENSG00000267731_AC005332.2', 'ENSG00000267733_AP005264.5', 'ENSG00000267750_RUNDC3A-AS1', 'ENSG00000267890_AC010624.2', 'ENSG00000267898_AC026803.2', 'ENSG00000267927_AC010320.1', 'ENSG00000268070_AC006539.2', 'ENSG00000268355_AC243960.3', 'ENSG00000268416_AC010329.1', 'ENSG00000268520_AC008750.5', 'ENSG00000268636_AC011495.2', 'ENSG00000268696_ZNF723', 'ENSG00000268777_AC020914.1', 'ENSG00000268849_SIGLEC22P', 'ENSG00000268903_AL627309.6', 'ENSG00000268983_AC005253.2', 'ENSG00000269019_HOMER3-AS1', 'ENSG00000269067_ZNF728', 'ENSG00000269103_RF00017', 'ENSG00000269274_AC078899.4', 'ENSG00000269288_AC092070.3', 'ENSG00000269352_PTOV1-AS2', 'ENSG00000269400_AC008734.2', 'ENSG00000269506_AC110792.2', 'ENSG00000269653_AC011479.3', 'ENSG00000269881_AC004754.1', 'ENSG00000269926_DDIT4-AS1', 'ENSG00000270048_AC068790.4', 'ENSG00000270050_AL035427.1', 'ENSG00000270503_YTHDF2P1', 'ENSG00000270706_PRMT1P1', 'ENSG00000270765_GAS2L2', 'ENSG00000270882_HIST2H4A', 'ENSG00000270906_MTND4P35', 'ENSG00000271013_LRRC37A9P', 'ENSG00000271129_AC009027.1', 'ENSG00000271259_AC010201.1', 'ENSG00000271524_BNIP3P17', 'ENSG00000271543_AC021443.1', 'ENSG00000271743_AF287957.1', 'ENSG00000271792_AC008667.4', 'ENSG00000271868_AC114810.1', 'ENSG00000271973_AC141002.1', 'ENSG00000271984_AL008726.1', 'ENSG00000271996_AC019080.4', 'ENSG00000272070_AC005618.1', 'ENSG00000272138_LINC01607', 'ENSG00000272150_NBPF25P', 'ENSG00000272265_AC034236.3', 'ENSG00000272279_AL512329.2', 'ENSG00000272473_AC006273.1', 'ENSG00000272510_AL121992.3', 'ENSG00000272582_AL031587.3', 'ENSG00000272695_GAS6-DT', 'ENSG00000272732_AC004982.1', 'ENSG00000272770_AC005696.2', 'ENSG00000272788_AP000864.1', 'ENSG00000272824_AC245100.7', 'ENSG00000272825_AL844908.1', 'ENSG00000272848_AL135910.1', 'ENSG00000272916_AC022400.6', 'ENSG00000273133_AC116651.1', 'ENSG00000273177_AC092954.2', 'ENSG00000273212_AC000068.2', 'ENSG00000273218_AC005776.2', 'ENSG00000273245_AC092653.1', 'ENSG00000273274_ZBTB8B', 'ENSG00000273312_AL121749.1', 'ENSG00000273325_AL008723.3', 'ENSG00000273369_AC096586.2', 'ENSG00000273474_AL157392.4', 'ENSG00000273599_AL731571.1', 'ENSG00000273724_AC106782.5', 'ENSG00000273870_AL138721.1', 'ENSG00000273920_AC103858.2', 'ENSG00000274023_AL360169.2', 'ENSG00000274029_AC069209.1', 'ENSG00000274114_ALOX15P1', 'ENSG00000274124_AC074029.3', 'ENSG00000274139_AC090164.2', 'ENSG00000274281_AC022929.2', 'ENSG00000274308_AC244093.1', 'ENSG00000274373_AC148476.1', 'ENSG00000274386_TMEM269', 'ENSG00000274403_AC090510.2', 'ENSG00000274570_SPDYE10P', 'ENSG00000274670_AC137590.2', 'ENSG00000274723_AC079906.1', 'ENSG00000274742_RF00017', 'ENSG00000274798_AC025166.1', 'ENSG00000274911_AL627230.2', 'ENSG00000275106_AC025594.2', 'ENSG00000275197_AC092794.2', 'ENSG00000275302_CCL4', 'ENSG00000275348_AC096861.1', 'ENSG00000275367_AC092111.1', 'ENSG00000275489_C17orf98', 'ENSG00000275527_AC100835.2', 'ENSG00000275995_AC109809.1', 'ENSG00000276070_CCL4L2', 'ENSG00000276255_AL136379.1', 'ENSG00000276282_AC022960.2', 'ENSG00000276547_PCDHGB5', 'ENSG00000276704_AL442067.2', 'ENSG00000276952_AL121772.3', 'ENSG00000276984_AL023881.1', 'ENSG00000276997_AL513314.2', 'ENSG00000277117_FP565260.3', 'ENSG00000277152_AC110048.2', 'ENSG00000277186_AC131212.1', 'ENSG00000277229_AC084781.1', 'ENSG00000277496_AL357033.4', 'ENSG00000277504_AC010536.3', 'ENSG00000277531_PNMA8C', 'ENSG00000278041_AL133325.3', 'ENSG00000278344_AC063943.1', 'ENSG00000278467_AC138393.3', 'ENSG00000278513_AC091046.2', 'ENSG00000278621_AC037198.2', 'ENSG00000278713_AC120114.2', 'ENSG00000278716_AC133540.1', 'ENSG00000278746_RN7SL660P', 'ENSG00000278774_RF00004', 'ENSG00000279091_AC026523.2', 'ENSG00000279130_AC091925.1', 'ENSG00000279141_LINC01451', 'ENSG00000279161_AC093503.3', 'ENSG00000279187_AC027601.5', 'ENSG00000279263_OR2L8', 'ENSG00000279315_AL158212.4', 'ENSG00000279319_AC105074.1', 'ENSG00000279332_AC090772.4', 'ENSG00000279339_AC100788.2', 'ENSG00000279365_AP000695.3', 'ENSG00000279378_AC009159.4', 'ENSG00000279384_AC080188.2', 'ENSG00000279404_AC008739.5', 'ENSG00000279417_AC019322.4', 'ENSG00000279444_AC135584.1', 'ENSG00000279486_OR2AG1', 'ENSG00000279530_AC092881.1', 'ENSG00000279590_AC005786.4', 'ENSG00000279619_AC020907.5', 'ENSG00000279633_AL137918.1', 'ENSG00000279636_LINC00216', 'ENSG00000279672_AP006621.5', 'ENSG00000279690_AP000280.1', 'ENSG00000279727_LINC02033', 'ENSG00000279861_AC073548.1', 'ENSG00000279913_AP001962.1', 'ENSG00000279970_AC023024.2', 'ENSG00000280055_TMEM75', 'ENSG00000280057_AL022069.2', 'ENSG00000280135_AL096816.1', 'ENSG00000280310_AC092437.1', 'ENSG00000280422_AC115284.2', 'ENSG00000280432_AP000962.2', 'ENSG00000280693_SH3PXD2A-AS1', 'ENSG00000281490_CICP14', 'ENSG00000281530_AC004461.2', 'ENSG00000281571_AC241585.2', 'ENSG00000282772_AL358790.1', 'ENSG00000282989_AP001206.1', 'ENSG00000282996_AC022021.1', 'ENSG00000283023_FRG1GP', 'ENSG00000283031_AC009242.1', 'ENSG00000283097_AL159152.1', 'ENSG00000283141_AL157832.3', 'ENSG00000283209_AC106858.1', 'ENSG00000283538_AC005972.3', 'ENSG00000284240_AC099062.1', 'ENSG00000284512_AC092718.8', 'ENSG00000284657_AL031432.5', 'ENSG00000284664_AL161756.3', 'ENSG00000284931_AC104389.5', 'ENSG00000285016_AC017002.6', 'ENSG00000285117_AC068724.4', 'ENSG00000285162_AC004593.3', 'ENSG00000285210_AL136382.1', 'ENSG00000285215_AC241377.4', 'ENSG00000285292_AC021097.2', 'ENSG00000285498_AC104389.6', 'ENSG00000285534_AL163541.1', 'ENSG00000285577_AC019127.1', 'ENSG00000285611_AC007132.1', 'ENSG00000285629_AL031847.2', 'ENSG00000285641_AL358472.6', 'ENSG00000285649_AL357079.2', 'ENSG00000285650_AL157827.2', 'ENSG00000285662_AL731733.1', 'ENSG00000285672_AL160396.2', 'ENSG00000285763_AL358777.1', 'ENSG00000285865_AC010285.3', 'ENSG00000285879_AC018628.2']
print('Constant cols:', len(constant_cols))

# important_cols = []
# for y_col in Y.columns:
#     important_cols += [x_col for x_col in X.columns if y_col in x_col]
# print(important_cols)
important_cols = ['ENSG00000114013_CD86', 'ENSG00000120217_CD274', 'ENSG00000196776_CD47', 'ENSG00000117091_CD48', 'ENSG00000101017_CD40', 'ENSG00000102245_CD40LG', 'ENSG00000169442_CD52', 'ENSG00000117528_ABCD3', 'ENSG00000168014_C2CD3', 'ENSG00000167851_CD300A', 'ENSG00000167850_CD300C', 'ENSG00000186407_CD300E', 'ENSG00000178789_CD300LB', 'ENSG00000186074_CD300LF', 'ENSG00000241399_CD302', 'ENSG00000167775_CD320', 'ENSG00000105383_CD33', 'ENSG00000174059_CD34', 'ENSG00000135218_CD36', 'ENSG00000104894_CD37', 'ENSG00000004468_CD38', 'ENSG00000167286_CD3D', 'ENSG00000198851_CD3E', 'ENSG00000117877_CD3EAP', 'ENSG00000074696_HACD3', 'ENSG00000015676_NUDCD3', 'ENSG00000161714_PLCD3', 'ENSG00000132300_PTCD3', 'ENSG00000082014_SMARCD3', 'ENSG00000121594_CD80', 'ENSG00000110651_CD81', 'ENSG00000238184_CD81-AS1', 'ENSG00000085117_CD82', 'ENSG00000112149_CD83', 'ENSG00000066294_CD84', 'ENSG00000114013_CD86', 'ENSG00000172116_CD8B', 'ENSG00000254126_CD8B2', 'ENSG00000177455_CD19', 'ENSG00000105383_CD33', 'ENSG00000173762_CD7', 'ENSG00000125726_CD70', 'ENSG00000137101_CD72', 'ENSG00000019582_CD74', 'ENSG00000105369_CD79A', 'ENSG00000007312_CD79B', 'ENSG00000090470_PDCD7', 'ENSG00000119688_ABCD4', 'ENSG00000010610_CD4', 'ENSG00000101017_CD40', 'ENSG00000102245_CD40LG', 'ENSG00000026508_CD44', 'ENSG00000117335_CD46', 'ENSG00000196776_CD47', 'ENSG00000117091_CD48', 'ENSG00000188921_HACD4', 'ENSG00000150593_PDCD4', 'ENSG00000203497_PDCD4-AS1', 'ENSG00000115556_PLCD4', 'ENSG00000026508_CD44', 'ENSG00000170458_CD14', 'ENSG00000117281_CD160', 'ENSG00000177575_CD163', 'ENSG00000135535_CD164', 'ENSG00000091972_CD200', 'ENSG00000163606_CD200R1', 'ENSG00000206531_CD200R1L', 'ENSG00000182685_BRICD5', 'ENSG00000111731_C2CD5', 'ENSG00000169442_CD52', 'ENSG00000143119_CD53', 'ENSG00000196352_CD55', 'ENSG00000116815_CD58', 'ENSG00000085063_CD59', 'ENSG00000105185_PDCD5', 'ENSG00000255909_PDCD5P1', 'ENSG00000145284_SCD5', 'ENSG00000167775_CD320', 'ENSG00000110848_CD69', 'ENSG00000139187_KLRG1', 'ENSG00000139193_CD27', 'ENSG00000215039_CD27-AS1', 'ENSG00000120217_CD274', 'ENSG00000103855_CD276', 'ENSG00000204287_HLA-DRA', 'ENSG00000196126_HLA-DRB1', 'ENSG00000198502_HLA-DRB5', 'ENSG00000229391_HLA-DRB6', 'ENSG00000116815_CD58', 'ENSG00000168329_CX3CR1', 'ENSG00000272398_CD24', 'ENSG00000122223_CD244', 'ENSG00000198821_CD247', 'ENSG00000122223_CD244', 'ENSG00000177575_CD163', 'ENSG00000112149_CD83', 'ENSG00000185963_BICD2', 'ENSG00000157617_C2CD2', 'ENSG00000172375_C2CD2L', 'ENSG00000116824_CD2', 'ENSG00000091972_CD200', 'ENSG00000163606_CD200R1', 'ENSG00000206531_CD200R1L', 'ENSG00000012124_CD22', 'ENSG00000150637_CD226', 'ENSG00000272398_CD24', 'ENSG00000122223_CD244', 'ENSG00000198821_CD247', 'ENSG00000139193_CD27', 'ENSG00000215039_CD27-AS1', 'ENSG00000120217_CD274', 'ENSG00000103855_CD276', 'ENSG00000198087_CD2AP', 'ENSG00000169217_CD2BP2', 'ENSG00000144554_FANCD2', 'ENSG00000206527_HACD2', 'ENSG00000170584_NUDCD2', 'ENSG00000071994_PDCD2', 'ENSG00000126249_PDCD2L', 'ENSG00000049883_PTCD2', 'ENSG00000186193_SAPCD2', 'ENSG00000108604_SMARCD2', 'ENSG00000185561_TLCD2', 'ENSG00000075035_WSCD2', 'ENSG00000150637_CD226', 'ENSG00000110651_CD81', 'ENSG00000238184_CD81-AS1', 'ENSG00000134061_CD180', 'ENSG00000004468_CD38', 'ENSG00000012124_CD22', 'ENSG00000150637_CD226', 'ENSG00000135404_CD63', 'ENSG00000135218_CD36', 'ENSG00000137101_CD72', 'ENSG00000125810_CD93', 'ENSG00000010278_CD9', 'ENSG00000125810_CD93', 'ENSG00000153283_CD96', 'ENSG00000002586_CD99', 'ENSG00000102181_CD99L2', 'ENSG00000223773_CD99P1', 'ENSG00000204592_HLA-E', 'ENSG00000085117_CD82', 'ENSG00000134256_CD101']
print('Important cols:', len(important_cols))
# Out:
# Constant cols: 1194
# Important cols: 144

# %% [markdown]
# We read train and test datasets, keep the important columns and convert the rest to sparse matrices.

# %%
# %%time

# Read train and convert to sparse matrix
X = pd.read_hdf(FP_CITE_TRAIN_INPUTS).drop(columns=constant_cols)
cell_index = X.index
meta = metadata_df.reindex(cell_index)
X0 = X[important_cols].values
print(f"Original X shape: {str(X.shape):14} {X.size*4/1024/1024/1024:2.3f} GByte")
gc.collect()
X = scipy.sparse.csr_matrix(X.values)
gc.collect()

# Read test and convert to sparse matrix
Xt = pd.read_hdf(FP_CITE_TEST_INPUTS).drop(columns=constant_cols)
cell_index_test = Xt.index
meta_test = metadata_df.reindex(cell_index_test)
X0t = Xt[important_cols].values
print(f"Original Xt shape: {str(Xt.shape):14} {Xt.size*4/1024/1024/1024:2.3f} GByte")
gc.collect()
Xt = scipy.sparse.csr_matrix(Xt.values)
# Out:
# <timed exec>:6: RuntimeWarning: overflow encountered in long_scalars
# Original X shape: (70988, 20856) 1.515 GByte
# <timed exec>:16: RuntimeWarning: overflow encountered in long_scalars
# Original Xt shape: (48663, 20856) -0.219 GByte
# Wall time: 1min 2s

# %% [markdown]
# We apply the truncated SVD to train and test together. The truncated SVD is memory-efficient. We concatenate the SVD output (64 components) with the 144 important features and get the arrays `X` and `Xt`, which will be the input to the Keras model.

# %%
def save(name, model):
    with open(name, 'wb') as f:
        pickle.dump(model, f)

# %%
# %%time
# Apply the singular value decomposition
both = scipy.sparse.vstack([X, Xt])
assert both.shape[0] == 119651
print(f"Shape of both before SVD: {both.shape}")

if USE_SAVED_PCA:
    svd = pickle.load(open('pca.pkl', 'rb'))
    both = svd.transform(both)
else:
    svd = TruncatedSVD(n_components=256, random_state=1) # 512 is possible
    both = svd.fit_transform(both)

    save('pca.pkl', svd)
print(f"Shape of both after SVD:  {both.shape}")
    
# Hstack the svd output with the important features
X = both[:70988]
Xt = both[70988:]
del both
X = np.hstack([X, X0])
Xt = np.hstack([Xt, X0t])
print(f"Reduced X shape:  {str(X.shape):14} {X.size*4/1024/1024/1024:2.3f} GByte")
print(f"Reduced Xt shape: {str(Xt.shape):14} {Xt.size*4/1024/1024/1024:2.3f} GByte")
# Out:
# Shape of both before SVD: (119651, 20856)
# Shape of both after SVD:  (119651, 256)
# Reduced X shape:  (70988, 400)   0.106 GByte
# Reduced Xt shape: (48663, 400)   0.073 GByte
# Wall time: 21.4 s

# %% [markdown]
# Finally, we read the target array `Y`:

# %%
# Read Y
Y = pd.read_hdf(FP_CITE_TRAIN_TARGETS)
y_columns = list(Y.columns)
Y = Y.values

# Normalize the targets row-wise: This doesn't change the correlations,
# and negative_correlation_loss depends on it
Y -= Y.mean(axis=1).reshape(-1, 1)
Y /= Y.std(axis=1).reshape(-1, 1)
    
print(f"Y shape: {str(Y.shape):14} {Y.size*4/1024/1024/1024:2.3f} GByte")
# Out:
# Y shape: (70988, 140)   0.037 GByte

# %% [markdown]
# # The model
#
# Our model is a sequential network consisting of a few dense layers. The hyperparameters will be tuned with KerasTuner.
#
# We use the `negative_correlation_loss` defined above as loss function.

# %%
from catboost import CatBoostRegressor
params = {'learning_rate': 0.1, 
          'depth': 7, 
          'l2_leaf_reg': 4, 
          'task_type': 'CPU',
          'loss_function': 'MultiRMSE', 
          'eval_metric': 'MultiRMSE',  
          'iterations': 200,
          'od_type': 'Iter', 
          'boosting_type': 'Plain', 
          'bootstrap_type': 'Bayesian', 
          'allow_const_label': True, 
          'random_state': 1
         }
# model = CatBoostRegressor(loss_function=negative_correlation_loss, eval_metric=negative_correlation_loss, **params)
model = CatBoostRegressor(**params)

# %%
n = 1

# %% [markdown]
# # Tuning with KerasTuner
#
# Now we let [KerasTuner](https://keras.io/keras_tuner/) optimize the hyperparameters. The tunable hyperparameters are:
# - the sizes of the hidden layers
# - the regularization factors
#
# If you want to save time, you can either set `max_trials` to a lower value or skip tuning completely and set `best_hp.values` manually. If you don't want to see all the output of the tuner, you can set `verbose` to 0 in the call to `tuner.search()`.

# %%
# np.random.seed(42)
# all_row_indices = np.arange(train_inputs.shape[0])
# np.random.shuffle(all_row_indices)

# kf = KFold(n_splits=5, shuffle=True, random_state=42)

# index = 0
# score = []

# # model = Ridge(copy_X=False)
# d = train_inputs.shape[0]//n
# for i in range(0, n*d, d):
#     print(f'start [{i}:{i+d}]')
#     ind = all_row_indices[i:i+d]    
#     for idx_tr, idx_va in kf.split(ind):
#         X = train_inputs[ind]
#         Y = train_target[ind] #.todense()
#         Yva = train_targets[ind][idx_va]
#         Xtr, Xva = X[idx_tr], X[idx_va]
#         Ytr = Y[idx_tr]
#         del X, Y
#         gc.collect()
#         print('Train...')
#         model.fit(Xtr, Ytr)
#         del Xtr, Ytr
#         gc.collect()
#         s = correlation_score(Yva.todense(), model.predict(Xva)@pca2.components_)
#         score.append(s)
#         print(index, s)
#         del Xva, Yva
#         gc.collect()
#         pkl_filename = f"model{index:02d}.pkl"
#         index += 1
#         with open(pkl_filename, 'wb') as file:
#             pickle.dump(model, file)
# #         break
# #     break
#     gc.collect()

# %% [markdown]
# # Cross-validation
#
# For cross-validation of the tuned model, we create three folds. In every fold, we train on the data of two donors and predict the third one. This scheme mimics the situation of the public leaderboard, where we train on three donors and predict the fourth one (see [EDA](https://www.kaggle.com/ambrosm/msci-eda-which-makes-sense)).
#
# The models are saved so that we can use them to compute the test predictions later.

# %%
# %%time
# Cross-validation
VERBOSE = 0 # set to 2 for more output, set to 0 for less output
EPOCHS = 1000
N_SPLITS = 5

np.random.seed(1)
tf.random.set_seed(1)

kf = KFold(n_splits=N_SPLITS)
score_list = []
index = 0

for fold, (idx_tr, idx_va) in enumerate(kf.split(X)):
    start_time = datetime.datetime.now()
    gc.collect()
    X_tr = X[idx_tr]
    y_tr = Y[idx_tr]
    X_va = X[idx_va]
    y_va = Y[idx_va]

    model.fit(X_tr, y_tr, eval_set=(X_va, y_va))

    del X_tr, y_tr
    pkl_filename = f"model{index:02d}.pkl"
    index += 1
    with open(pkl_filename, 'wb') as file:
        pickle.dump(model, file)
    
    # We validate the model
    y_va_pred = model.predict(X_va)
    corrscore = correlation_score(y_va, y_va_pred)

    print(f"corr =  {corrscore:.5f}")
    del X_va#, y_va, y_va_pred
    score_list.append(corrscore)

# Show overall score
print(f"{Fore.GREEN}{Style.BRIGHT}Average  corr = {np.array(score_list).mean():.5f}{Style.RESET_ALL}")
# Out:
# 0:	learn: 6.8409562	test: 6.7676015	best: 6.7676015 (0)	total: 11.6s	remaining: 38m 34s
# 1:	learn: 6.6709619	test: 6.6185713	best: 6.6185713 (1)	total: 23.3s	remaining: 38m 27s
# 2:	learn: 6.5269882	test: 6.4880592	best: 6.4880592 (2)	total: 34.9s	remaining: 38m 14s
# 3:	learn: 6.4045022	test: 6.3787557	best: 6.3787557 (3)	total: 46.6s	remaining: 38m 3s
# 4:	learn: 6.2979832	test: 6.2782339	best: 6.2782339 (4)	total: 58.3s	remaining: 37m 53s
# 5:	learn: 6.2027006	test: 6.1934404	best: 6.1934404 (5)	total: 1m 9s	remaining: 37m 42s
# 6:	learn: 6.1233081	test: 6.1277061	best: 6.1277061 (6)	total: 1m 21s	remaining: 37m 31s
# 7:	learn: 6.0521598	test: 6.0692032	best: 6.0692032 (7)	total: 1m 33s	remaining: 37m 21s
# 8:	learn: 5.9897598	test: 6.0098751	best: 6.0098751 (8)	total: 1m 45s	remaining: 37m 10s
# 9:	learn: 5.9382855	test: 5.9649912	best: 5.9649912 (9)	total: 1m 56s	remaining: 37m 1s
# 10:	learn: 5.8821300	test: 5.9134966	best: 5.9134966 (10)	total: 2m 8s	remaining: 36m 50s
# 11:	learn: 5.8384645	test: 5.8809960	best: 5.8809960 (11)	total: 2m 20s	remaining: 36m 41s
# 12:	learn: 5.7993298	test: 5.8490907	best: 5.8490907 (12)	total: 2m 32s	remaining: 36m 30s
# 13:	learn: 5.7655647	test: 5.8158065	best: 5.8158065 (13)	total: 2m 43s	remaining: 36m 18s
# 14:	learn: 5.7341888	test: 5.7904654	best: 5.7904654 (14)	total: 2m 55s	remaining: 36m 7s
# 15:	learn: 5.7056866	test: 5.7665259	best: 5.7665259 (15)	total: 3m 7s	remaining: 35m 55s
# 16:	learn: 5.6815504	test: 5.7458719	best: 5.7458719 (16)	total: 3m 19s	remaining: 35m 44s
# 17:	learn: 5.6595455	test: 5.7311794	best: 5.7311794 (17)	total: 3m 31s	remaining: 35m 33s
# 18:	learn: 5.6364959	test: 5.7110645	best: 5.7110645 (18)	total: 3m 42s	remaining: 35m 21s
# 19:	learn: 5.6185989	test: 5.6958112	best: 5.6958112 (19)	total: 3m 54s	remaining: 35m 10s
# 20:	learn: 5.5987621	test: 5.6792770	best: 5.6792770 (20)	total: 4m 6s	remaining: 35m
# 21:	learn: 5.5804267	test: 5.6616988	best: 5.6616988 (21)	total: 4m 18s	remaining: 34m 49s
# 22:	learn: 5.5661135	test: 5.6485967	best: 5.6485967 (22)	total: 4m 29s	remaining: 34m 37s
# 23:	learn: 5.5522774	test: 5.6369146	best: 5.6369146 (23)	total: 4m 41s	remaining: 34m 26s
# 24:	learn: 5.5384913	test: 5.6241809	best: 5.6241809 (24)	total: 4m 53s	remaining: 34m 15s
# 25:	learn: 5.5237126	test: 5.6100454	best: 5.6100454 (25)	total: 5m 5s	remaining: 34m 4s
# 26:	learn: 5.5103544	test: 5.5952116	best: 5.5952116 (26)	total: 5m 17s	remaining: 33m 52s
# 27:	learn: 5.4995948	test: 5.5850742	best: 5.5850742 (27)	total: 5m 28s	remaining: 33m 40s
# 28:	learn: 5.4892947	test: 5.5757898	best: 5.5757898 (28)	total: 5m 40s	remaining: 33m 28s
# 29:	learn: 5.4797551	test: 5.5681526	best: 5.5681526 (29)	total: 5m 52s	remaining: 33m 16s
# 30:	learn: 5.4686138	test: 5.5592530	best: 5.5592530 (30)	total: 6m 4s	remaining: 33m 4s
# 31:	learn: 5.4599825	test: 5.5529339	best: 5.5529339 (31)	total: 6m 15s	remaining: 32m 52s
# 32:	learn: 5.4506399	test: 5.5464881	best: 5.5464881 (32)	total: 6m 27s	remaining: 32m 40s
# 33:	learn: 5.4426986	test: 5.5398127	best: 5.5398127 (33)	total: 6m 39s	remaining: 32m 28s
# 34:	learn: 5.4351189	test: 5.5341580	best: 5.5341580 (34)	total: 6m 50s	remaining: 32m 15s
# 35:	learn: 5.4265299	test: 5.5252222	best: 5.5252222 (35)	total: 7m 2s	remaining: 32m 4s
# 36:	learn: 5.4197400	test: 5.5167460	best: 5.5167460 (36)	total: 7m 13s	remaining: 31m 51s
# 37:	learn: 5.4125175	test: 5.5110494	best: 5.5110494 (37)	total: 7m 25s	remaining: 31m 39s
# 38:	learn: 5.4052816	test: 5.5061414	best: 5.5061414 (38)	total: 7m 37s	remaining: 31m 27s
# 39:	learn: 5.3998358	test: 5.5025551	best: 5.5025551 (39)	total: 7m 48s	remaining: 31m 15s
# 40:	learn: 5.3940614	test: 5.4980284	best: 5.4980284 (40)	total: 8m	remaining: 31m 3s
# 41:	learn: 5.3885838	test: 5.4928065	best: 5.4928065 (41)	total: 8m 12s	remaining: 30m 51s
# 42:	learn: 5.3835996	test: 5.4885298	best: 5.4885298 (42)	total: 8m 23s	remaining: 30m 39s
# 43:	learn: 5.3776780	test: 5.4838581	best: 5.4838581 (43)	total: 8m 35s	remaining: 30m 27s
# 44:	learn: 5.3704428	test: 5.4769601	best: 5.4769601 (44)	total: 8m 47s	remaining: 30m 15s
# 45:	learn: 5.3655183	test: 5.4720787	best: 5.4720787 (45)	total: 8m 58s	remaining: 30m 3s
# 46:	learn: 5.3616895	test: 5.4691666	best: 5.4691666 (46)	total: 9m 10s	remaining: 29m 50s
# 47:	learn: 5.3584719	test: 5.4670205	best: 5.4670205 (47)	total: 9m 21s	remaining: 29m 38s
# 48:	learn: 5.3534342	test: 5.4632462	best: 5.4632462 (48)	total: 9m 33s	remaining: 29m 26s
# 49:	learn: 5.3479381	test: 5.4586983	best: 5.4586983 (49)	total: 9m 44s	remaining: 29m 14s
# 50:	learn: 5.3427429	test: 5.4565197	best: 5.4565197 (50)	total: 9m 56s	remaining: 29m 2s
# 51:	learn: 5.3376530	test: 5.4526846	best: 5.4526846 (51)	total: 10m 8s	remaining: 28m 50s
# 52:	learn: 5.3339107	test: 5.4508445	best: 5.4508445 (52)	total: 10m 19s	remaining: 28m 39s
# 53:	learn: 5.3306733	test: 5.4490632	best: 5.4490632 (53)	total: 10m 31s	remaining: 28m 27s
# 54:	learn: 5.3264469	test: 5.4457789	best: 5.4457789 (54)	total: 10m 43s	remaining: 28m 15s
# 55:	learn: 5.3227769	test: 5.4416589	best: 5.4416589 (55)	total: 10m 54s	remaining: 28m 2s
# 56:	learn: 5.3189346	test: 5.4389934	best: 5.4389934 (56)	total: 11m 6s	remaining: 27m 51s
# 57:	learn: 5.3143741	test: 5.4348636	best: 5.4348636 (57)	total: 11m 17s	remaining: 27m 39s
# 58:	learn: 5.3114697	test: 5.4322396	best: 5.4322396 (58)	total: 11m 29s	remaining: 27m 27s
# 59:	learn: 5.3084656	test: 5.4306785	best: 5.4306785 (59)	total: 11m 41s	remaining: 27m 15s
# 60:	learn: 5.3047497	test: 5.4280636	best: 5.4280636 (60)	total: 11m 52s	remaining: 27m 4s
# 61:	learn: 5.3016254	test: 5.4258249	best: 5.4258249 (61)	total: 12m 4s	remaining: 26m 51s
# 62:	learn: 5.2989134	test: 5.4254951	best: 5.4254951 (62)	total: 12m 15s	remaining: 26m 40s
# 63:	learn: 5.2958367	test: 5.4235551	best: 5.4235551 (63)	total: 12m 27s	remaining: 26m 28s
# 64:	learn: 5.2930825	test: 5.4214007	best: 5.4214007 (64)	total: 12m 39s	remaining: 26m 16s
# 65:	learn: 5.2896907	test: 5.4192911	best: 5.4192911 (65)	total: 12m 50s	remaining: 26m 5s
# 66:	learn: 5.2867519	test: 5.4177874	best: 5.4177874 (66)	total: 13m 2s	remaining: 25m 53s
# 67:	learn: 5.2841538	test: 5.4163529	best: 5.4163529 (67)	total: 13m 14s	remaining: 25m 41s
# 68:	learn: 5.2804683	test: 5.4135504	best: 5.4135504 (68)	total: 13m 25s	remaining: 25m 30s
# 69:	learn: 5.2785704	test: 5.4125773	best: 5.4125773 (69)	total: 13m 37s	remaining: 25m 18s
# 70:	learn: 5.2759908	test: 5.4113791	best: 5.4113791 (70)	total: 13m 49s	remaining: 25m 6s
# 71:	learn: 5.2733779	test: 5.4104231	best: 5.4104231 (71)	total: 14m 1s	remaining: 24m 55s
# 72:	learn: 5.2707241	test: 5.4086367	best: 5.4086367 (72)	total: 14m 12s	remaining: 24m 43s
# 73:	learn: 5.2682335	test: 5.4056305	best: 5.4056305 (73)	total: 14m 24s	remaining: 24m 31s
# 74:	learn: 5.2651520	test: 5.4044165	best: 5.4044165 (74)	total: 14m 36s	remaining: 24m 20s
# 75:	learn: 5.2629801	test: 5.4034954	best: 5.4034954 (75)	total: 14m 48s	remaining: 24m 8s
# 76:	learn: 5.2605768	test: 5.4017226	best: 5.4017226 (76)	total: 14m 59s	remaining: 23m 57s
# 77:	learn: 5.2582027	test: 5.4001048	best: 5.4001048 (77)	total: 15m 11s	remaining: 23m 45s
# 78:	learn: 5.2563628	test: 5.3990221	best: 5.3990221 (78)	total: 15m 22s	remaining: 23m 33s
# 79:	learn: 5.2536832	test: 5.3977325	best: 5.3977325 (79)	total: 15m 34s	remaining: 23m 21s
# 80:	learn: 5.2513525	test: 5.3963520	best: 5.3963520 (80)	total: 15m 45s	remaining: 23m 9s
# 81:	learn: 5.2487715	test: 5.3959525	best: 5.3959525 (81)	total: 15m 57s	remaining: 22m 57s
# 82:	learn: 5.2464342	test: 5.3952086	best: 5.3952086 (82)	total: 16m 9s	remaining: 22m 46s
# 83:	learn: 5.2439538	test: 5.3942493	best: 5.3942493 (83)	total: 16m 20s	remaining: 22m 34s
# 84:	learn: 5.2413891	test: 5.3924170	best: 5.3924170 (84)	total: 16m 32s	remaining: 22m 22s
# 85:	learn: 5.2399631	test: 5.3918529	best: 5.3918529 (85)	total: 16m 43s	remaining: 22m 10s
# 86:	learn: 5.2372364	test: 5.3910243	best: 5.3910243 (86)	total: 16m 55s	remaining: 21m 58s
# 87:	learn: 5.2344657	test: 5.3897311	best: 5.3897311 (87)	total: 17m 6s	remaining: 21m 46s
# 88:	learn: 5.2321184	test: 5.3870709	best: 5.3870709 (88)	total: 17m 18s	remaining: 21m 35s
# 89:	learn: 5.2293524	test: 5.3865207	best: 5.3865207 (89)	total: 17m 29s	remaining: 21m 23s
# 90:	learn: 5.2269800	test: 5.3853513	best: 5.3853513 (90)	total: 17m 41s	remaining: 21m 11s
# 91:	learn: 5.2247877	test: 5.3841070	best: 5.3841070 (91)	total: 17m 52s	remaining: 20m 59s
# 92:	learn: 5.2223059	test: 5.3827715	best: 5.3827715 (92)	total: 18m 4s	remaining: 20m 47s
# 93:	learn: 5.2209025	test: 5.3821886	best: 5.3821886 (93)	total: 18m 15s	remaining: 20m 35s
# 94:	learn: 5.2182026	test: 5.3798728	best: 5.3798728 (94)	total: 18m 27s	remaining: 20m 24s
# 95:	learn: 5.2165740	test: 5.3770589	best: 5.3770589 (95)	total: 18m 38s	remaining: 20m 11s
# 96:	learn: 5.2144060	test: 5.3756990	best: 5.3756990 (96)	total: 18m 50s	remaining: 20m
# 97:	learn: 5.2121746	test: 5.3748312	best: 5.3748312 (97)	total: 19m 1s	remaining: 19m 48s
# 98:	learn: 5.2103755	test: 5.3741488	best: 5.3741488 (98)	total: 19m 13s	remaining: 19m 36s
# 99:	learn: 5.2090960	test: 5.3736134	best: 5.3736134 (99)	total: 19m 24s	remaining: 19m 24s
# 100:	learn: 5.2071617	test: 5.3722241	best: 5.3722241 (100)	total: 19m 36s	remaining: 19m 12s
# 101:	learn: 5.2052701	test: 5.3715225	best: 5.3715225 (101)	total: 19m 47s	remaining: 19m 1s
# 102:	learn: 5.2027546	test: 5.3696660	best: 5.3696660 (102)	total: 19m 59s	remaining: 18m 49s
# 103:	learn: 5.2006525	test: 5.3686696	best: 5.3686696 (103)	total: 20m 10s	remaining: 18m 37s
# 104:	learn: 5.1984450	test: 5.3678063	best: 5.3678063 (104)	total: 20m 22s	remaining: 18m 25s
# 105:	learn: 5.1955974	test: 5.3668613	best: 5.3668613 (105)	total: 20m 34s	remaining: 18m 14s
# 106:	learn: 5.1935221	test: 5.3657593	best: 5.3657593 (106)	total: 20m 45s	remaining: 18m 2s
# 107:	learn: 5.1910178	test: 5.3635725	best: 5.3635725 (107)	total: 20m 57s	remaining: 17m 50s
# 108:	learn: 5.1881775	test: 5.3603845	best: 5.3603845 (108)	total: 21m 8s	remaining: 17m 39s
# 109:	learn: 5.1861914	test: 5.3595402	best: 5.3595402 (109)	total: 21m 20s	remaining: 17m 27s
# 110:	learn: 5.1840069	test: 5.3580865	best: 5.3580865 (110)	total: 21m 31s	remaining: 17m 15s
# 111:	learn: 5.1818465	test: 5.3574564	best: 5.3574564 (111)	total: 21m 43s	remaining: 17m 3s
# 112:	learn: 5.1795518	test: 5.3543506	best: 5.3543506 (112)	total: 21m 54s	remaining: 16m 52s
# 113:	learn: 5.1780500	test: 5.3528499	best: 5.3528499 (113)	total: 22m 5s	remaining: 16m 40s
# 114:	learn: 5.1760942	test: 5.3518827	best: 5.3518827 (114)	total: 22m 17s	remaining: 16m 28s
# 115:	learn: 5.1743115	test: 5.3512531	best: 5.3512531 (115)	total: 22m 28s	remaining: 16m 16s
# 116:	learn: 5.1725676	test: 5.3500923	best: 5.3500923 (116)	total: 22m 40s	remaining: 16m 4s
# 117:	learn: 5.1709521	test: 5.3498329	best: 5.3498329 (117)	total: 22m 51s	remaining: 15m 53s
# 118:	learn: 5.1693347	test: 5.3492257	best: 5.3492257 (118)	total: 23m 2s	remaining: 15m 41s
# 119:	learn: 5.1677293	test: 5.3487028	best: 5.3487028 (119)	total: 23m 14s	remaining: 15m 29s
# 120:	learn: 5.1657101	test: 5.3480403	best: 5.3480403 (120)	total: 23m 25s	remaining: 15m 17s
# 121:	learn: 5.1642996	test: 5.3472873	best: 5.3472873 (121)	total: 23m 37s	remaining: 15m 6s
# 122:	learn: 5.1624267	test: 5.3458085	best: 5.3458085 (122)	total: 23m 48s	remaining: 14m 54s
# 123:	learn: 5.1611505	test: 5.3451612	best: 5.3451612 (123)	total: 23m 59s	remaining: 14m 42s
# 124:	learn: 5.1591386	test: 5.3440086	best: 5.3440086 (124)	total: 24m 11s	remaining: 14m 30s
# 125:	learn: 5.1568898	test: 5.3431753	best: 5.3431753 (125)	total: 24m 22s	remaining: 14m 19s
# 126:	learn: 5.1553147	test: 5.3412145	best: 5.3412145 (126)	total: 24m 34s	remaining: 14m 7s
# 127:	learn: 5.1530822	test: 5.3403209	best: 5.3403209 (127)	total: 24m 45s	remaining: 13m 55s
# 128:	learn: 5.1514570	test: 5.3395300	best: 5.3395300 (128)	total: 24m 57s	remaining: 13m 43s
# 129:	learn: 5.1500154	test: 5.3387616	best: 5.3387616 (129)	total: 25m 8s	remaining: 13m 32s
# 130:	learn: 5.1476579	test: 5.3378617	best: 5.3378617 (130)	total: 25m 20s	remaining: 13m 20s
# 131:	learn: 5.1457006	test: 5.3371480	best: 5.3371480 (131)	total: 25m 31s	remaining: 13m 8s
# 132:	learn: 5.1444832	test: 5.3361690	best: 5.3361690 (132)	total: 25m 42s	remaining: 12m 57s
# 133:	learn: 5.1428736	test: 5.3351376	best: 5.3351376 (133)	total: 25m 53s	remaining: 12m 45s
# 134:	learn: 5.1412905	test: 5.3343392	best: 5.3343392 (134)	total: 26m 5s	remaining: 12m 33s
# 135:	learn: 5.1397189	test: 5.3329497	best: 5.3329497 (135)	total: 26m 16s	remaining: 12m 21s
# 136:	learn: 5.1378762	test: 5.3316602	best: 5.3316602 (136)	total: 26m 28s	remaining: 12m 10s
# 137:	learn: 5.1359769	test: 5.3307539	best: 5.3307539 (137)	total: 26m 39s	remaining: 11m 58s
# 138:	learn: 5.1343438	test: 5.3298102	best: 5.3298102 (138)	total: 26m 51s	remaining: 11m 47s
# 139:	learn: 5.1322909	test: 5.3275748	best: 5.3275748 (139)	total: 27m 2s	remaining: 11m 35s
# 140:	learn: 5.1305713	test: 5.3263320	best: 5.3263320 (140)	total: 27m 13s	remaining: 11m 23s
# 141:	learn: 5.1287898	test: 5.3255580	best: 5.3255580 (141)	total: 27m 25s	remaining: 11m 12s
# 142:	learn: 5.1273928	test: 5.3250966	best: 5.3250966 (142)	total: 27m 36s	remaining: 11m
# 143:	learn: 5.1254647	test: 5.3245057	best: 5.3245057 (143)	total: 27m 48s	remaining: 10m 48s
# 144:	learn: 5.1239499	test: 5.3238830	best: 5.3238830 (144)	total: 27m 59s	remaining: 10m 37s
# 145:	learn: 5.1218476	test: 5.3230531	best: 5.3230531 (145)	total: 28m 11s	remaining: 10m 25s
# 146:	learn: 5.1207674	test: 5.3221818	best: 5.3221818 (146)	total: 28m 22s	remaining: 10m 13s
# 147:	learn: 5.1191531	test: 5.3215973	best: 5.3215973 (147)	total: 28m 33s	remaining: 10m 2s
# 148:	learn: 5.1173765	test: 5.3199341	best: 5.3199341 (148)	total: 28m 45s	remaining: 9m 50s
# 149:	learn: 5.1158083	test: 5.3197897	best: 5.3197897 (149)	total: 28m 56s	remaining: 9m 38s
# 150:	learn: 5.1144774	test: 5.3185423	best: 5.3185423 (150)	total: 29m 8s	remaining: 9m 27s
# 151:	learn: 5.1135511	test: 5.3170986	best: 5.3170986 (151)	total: 29m 19s	remaining: 9m 15s
# 152:	learn: 5.1122605	test: 5.3168381	best: 5.3168381 (152)	total: 29m 30s	remaining: 9m 3s
# 153:	learn: 5.1103122	test: 5.3157322	best: 5.3157322 (153)	total: 29m 42s	remaining: 8m 52s
# 154:	learn: 5.1094393	test: 5.3154232	best: 5.3154232 (154)	total: 29m 53s	remaining: 8m 40s
# 155:	learn: 5.1085287	test: 5.3150606	best: 5.3150606 (155)	total: 30m 4s	remaining: 8m 29s
# 156:	learn: 5.1075513	test: 5.3146337	best: 5.3146337 (156)	total: 30m 16s	remaining: 8m 17s
# 157:	learn: 5.1059867	test: 5.3142371	best: 5.3142371 (157)	total: 30m 27s	remaining: 8m 5s
# 158:	learn: 5.1050391	test: 5.3137289	best: 5.3137289 (158)	total: 30m 38s	remaining: 7m 54s
# 159:	learn: 5.1036561	test: 5.3131156	best: 5.3131156 (159)	total: 30m 50s	remaining: 7m 42s
# 160:	learn: 5.1021414	test: 5.3124493	best: 5.3124493 (160)	total: 31m 1s	remaining: 7m 30s
# 161:	learn: 5.1011555	test: 5.3115633	best: 5.3115633 (161)	total: 31m 12s	remaining: 7m 19s
# 162:	learn: 5.0994812	test: 5.3114484	best: 5.3114484 (162)	total: 31m 24s	remaining: 7m 7s
# 163:	learn: 5.0980751	test: 5.3108549	best: 5.3108549 (163)	total: 31m 35s	remaining: 6m 56s
# 164:	learn: 5.0967803	test: 5.3105312	best: 5.3105312 (164)	total: 31m 47s	remaining: 6m 44s
# 165:	learn: 5.0954223	test: 5.3103197	best: 5.3103197 (165)	total: 31m 58s	remaining: 6m 32s
# 166:	learn: 5.0945260	test: 5.3099992	best: 5.3099992 (166)	total: 32m 10s	remaining: 6m 21s
# 167:	learn: 5.0933419	test: 5.3092906	best: 5.3092906 (167)	total: 32m 21s	remaining: 6m 9s
# 168:	learn: 5.0920803	test: 5.3088250	best: 5.3088250 (168)	total: 32m 32s	remaining: 5m 58s
# 169:	learn: 5.0904641	test: 5.3080547	best: 5.3080547 (169)	total: 32m 44s	remaining: 5m 46s
# 170:	learn: 5.0896118	test: 5.3075207	best: 5.3075207 (170)	total: 32m 55s	remaining: 5m 35s
# 171:	learn: 5.0881056	test: 5.3067926	best: 5.3067926 (171)	total: 33m 6s	remaining: 5m 23s
# 172:	learn: 5.0867078	test: 5.3062033	best: 5.3062033 (172)	total: 33m 18s	remaining: 5m 11s
# 173:	learn: 5.0856972	test: 5.3057610	best: 5.3057610 (173)	total: 33m 29s	remaining: 5m
# 174:	learn: 5.0840879	test: 5.3054976	best: 5.3054976 (174)	total: 33m 41s	remaining: 4m 48s
# 175:	learn: 5.0828968	test: 5.3047471	best: 5.3047471 (175)	total: 33m 52s	remaining: 4m 37s
# 176:	learn: 5.0813877	test: 5.3045106	best: 5.3045106 (176)	total: 34m 3s	remaining: 4m 25s
# 177:	learn: 5.0805720	test: 5.3037203	best: 5.3037203 (177)	total: 34m 14s	remaining: 4m 13s
# 178:	learn: 5.0787395	test: 5.3033011	best: 5.3033011 (178)	total: 34m 26s	remaining: 4m 2s
# 179:	learn: 5.0778002	test: 5.3028707	best: 5.3028707 (179)	total: 34m 37s	remaining: 3m 50s
# 180:	learn: 5.0764315	test: 5.3021866	best: 5.3021866 (180)	total: 34m 49s	remaining: 3m 39s
# 181:	learn: 5.0751503	test: 5.3013307	best: 5.3013307 (181)	total: 35m	remaining: 3m 27s
# 182:	learn: 5.0740294	test: 5.3009673	best: 5.3009673 (182)	total: 35m 11s	remaining: 3m 16s
# 183:	learn: 5.0732077	test: 5.3006848	best: 5.3006848 (183)	total: 35m 23s	remaining: 3m 4s
# 184:	learn: 5.0721054	test: 5.3001075	best: 5.3001075 (184)	total: 35m 34s	remaining: 2m 53s
# 185:	learn: 5.0710808	test: 5.2997759	best: 5.2997759 (185)	total: 35m 45s	remaining: 2m 41s
# 186:	learn: 5.0697631	test: 5.2994521	best: 5.2994521 (186)	total: 35m 57s	remaining: 2m 29s
# 187:	learn: 5.0683679	test: 5.2992607	best: 5.2992607 (187)	total: 36m 8s	remaining: 2m 18s
# 188:	learn: 5.0669923	test: 5.2988278	best: 5.2988278 (188)	total: 36m 20s	remaining: 2m 6s
# 189:	learn: 5.0658059	test: 5.2978094	best: 5.2978094 (189)	total: 36m 31s	remaining: 1m 55s
# 190:	learn: 5.0644146	test: 5.2968150	best: 5.2968150 (190)	total: 36m 42s	remaining: 1m 43s
# 191:	learn: 5.0638043	test: 5.2965590	best: 5.2965590 (191)	total: 36m 53s	remaining: 1m 32s
# 192:	learn: 5.0624157	test: 5.2961024	best: 5.2961024 (192)	total: 37m 5s	remaining: 1m 20s
# 193:	learn: 5.0619235	test: 5.2959854	best: 5.2959854 (193)	total: 37m 16s	remaining: 1m 9s
# 194:	learn: 5.0606148	test: 5.2950088	best: 5.2950088 (194)	total: 37m 27s	remaining: 57.6s
# 195:	learn: 5.0597300	test: 5.2946249	best: 5.2946249 (195)	total: 37m 39s	remaining: 46.1s
# 196:	learn: 5.0590312	test: 5.2942816	best: 5.2942816 (196)	total: 37m 50s	remaining: 34.6s
# 197:	learn: 5.0579706	test: 5.2939034	best: 5.2939034 (197)	total: 38m 1s	remaining: 23s
# 198:	learn: 5.0566079	test: 5.2927598	best: 5.2927598 (198)	total: 38m 13s	remaining: 11.5s
# 199:	learn: 5.0551989	test: 5.2924684	best: 5.2924684 (199)	total: 38m 24s	remaining: 0us
#
# bestTest = 5.292468414
# bestIteration = 199
#
# corr =  0.89426
# 0:	learn: 6.8058249	test: 6.9151405	best: 6.9151405 (0)	total: 11.5s	remaining: 38m 12s
# 1:	learn: 6.6505519	test: 6.7474540	best: 6.7474540 (1)	total: 23s	remaining: 38m 1s
# 2:	learn: 6.5138810	test: 6.5975360	best: 6.5975360 (2)	total: 34.7s	remaining: 37m 56s
# 3:	learn: 6.3921961	test: 6.4583882	best: 6.4583882 (3)	total: 46.2s	remaining: 37m 45s
# 4:	learn: 6.2892761	test: 6.3454290	best: 6.3454290 (4)	total: 57.8s	remaining: 37m 34s
# 5:	learn: 6.1983515	test: 6.2429830	best: 6.2429830 (5)	total: 1m 9s	remaining: 37m 23s
# 6:	learn: 6.1184549	test: 6.1551327	best: 6.1551327 (6)	total: 1m 20s	remaining: 37m 12s
# 7:	learn: 6.0526958	test: 6.0859567	best: 6.0859567 (7)	total: 1m 32s	remaining: 37m 3s
# 8:	learn: 5.9884970	test: 6.0197429	best: 6.0197429 (8)	total: 1m 44s	remaining: 36m 57s
# 9:	learn: 5.9387650	test: 5.9682486	best: 5.9682486 (9)	total: 1m 56s	remaining: 36m 45s
# 10:	learn: 5.8897992	test: 5.9127669	best: 5.9127669 (10)	total: 2m 7s	remaining: 36m 31s
# 11:	learn: 5.8498485	test: 5.8660579	best: 5.8660579 (11)	total: 2m 19s	remaining: 36m 20s
# 12:	learn: 5.8133145	test: 5.8286866	best: 5.8286866 (12)	total: 2m 30s	remaining: 36m 9s
# 13:	learn: 5.7792765	test: 5.7950527	best: 5.7950527 (13)	total: 2m 42s	remaining: 35m 56s
# 14:	learn: 5.7458798	test: 5.7625623	best: 5.7625623 (14)	total: 2m 53s	remaining: 35m 45s
# 15:	learn: 5.7202296	test: 5.7372213	best: 5.7372213 (15)	total: 3m 5s	remaining: 35m 34s
# 16:	learn: 5.6954385	test: 5.7142798	best: 5.7142798 (16)	total: 3m 17s	remaining: 35m 23s
# 17:	learn: 5.6692027	test: 5.6887894	best: 5.6887894 (17)	total: 3m 28s	remaining: 35m 11s
# 18:	learn: 5.6484855	test: 5.6707483	best: 5.6707483 (18)	total: 3m 40s	remaining: 34m 59s
# 19:	learn: 5.6281331	test: 5.6484067	best: 5.6484067 (19)	total: 3m 51s	remaining: 34m 47s
# 20:	learn: 5.6075183	test: 5.6306474	best: 5.6306474 (20)	total: 4m 3s	remaining: 34m 34s
# 21:	learn: 5.5890491	test: 5.6103021	best: 5.6103021 (21)	total: 4m 15s	remaining: 34m 23s
# 22:	learn: 5.5731343	test: 5.5968213	best: 5.5968213 (22)	total: 4m 26s	remaining: 34m 12s
# 23:	learn: 5.5586974	test: 5.5789341	best: 5.5789341 (23)	total: 4m 38s	remaining: 34m 1s
# 24:	learn: 5.5446664	test: 5.5690905	best: 5.5690905 (24)	total: 4m 49s	remaining: 33m 49s
# 25:	learn: 5.5321700	test: 5.5571351	best: 5.5571351 (25)	total: 5m 1s	remaining: 33m 37s
# 26:	learn: 5.5187877	test: 5.5440586	best: 5.5440586 (26)	total: 5m 13s	remaining: 33m 25s
# 27:	learn: 5.5058877	test: 5.5330795	best: 5.5330795 (27)	total: 5m 24s	remaining: 33m 13s
# 28:	learn: 5.4953189	test: 5.5218229	best: 5.5218229 (28)	total: 5m 36s	remaining: 33m 1s
# 29:	learn: 5.4851570	test: 5.5153991	best: 5.5153991 (29)	total: 5m 47s	remaining: 32m 50s
# 30:	learn: 5.4730997	test: 5.5039289	best: 5.5039289 (30)	total: 5m 59s	remaining: 32m 38s
# 31:	learn: 5.4617931	test: 5.4949008	best: 5.4949008 (31)	total: 6m 10s	remaining: 32m 27s
# 32:	learn: 5.4517073	test: 5.4868915	best: 5.4868915 (32)	total: 6m 22s	remaining: 32m 14s
# 33:	learn: 5.4415863	test: 5.4779302	best: 5.4779302 (33)	total: 6m 33s	remaining: 32m 3s
# 34:	learn: 5.4339972	test: 5.4710584	best: 5.4710584 (34)	total: 6m 45s	remaining: 31m 52s
# 35:	learn: 5.4259367	test: 5.4635191	best: 5.4635191 (35)	total: 6m 57s	remaining: 31m 40s
# 36:	learn: 5.4197492	test: 5.4559982	best: 5.4559982 (36)	total: 7m 8s	remaining: 31m 28s
# 37:	learn: 5.4127997	test: 5.4483850	best: 5.4483850 (37)	total: 7m 20s	remaining: 31m 16s
# 38:	learn: 5.4077094	test: 5.4453584	best: 5.4453584 (38)	total: 7m 31s	remaining: 31m 5s
# 39:	learn: 5.4012385	test: 5.4402754	best: 5.4402754 (39)	total: 7m 43s	remaining: 30m 53s
# 40:	learn: 5.3954193	test: 5.4358320	best: 5.4358320 (40)	total: 7m 55s	remaining: 30m 42s
# 41:	learn: 5.3881464	test: 5.4300023	best: 5.4300023 (41)	total: 8m 6s	remaining: 30m 30s
# 42:	learn: 5.3821497	test: 5.4251129	best: 5.4251129 (42)	total: 8m 18s	remaining: 30m 19s
# 43:	learn: 5.3766914	test: 5.4220724	best: 5.4220724 (43)	total: 8m 29s	remaining: 30m 7s
# 44:	learn: 5.3721482	test: 5.4188254	best: 5.4188254 (44)	total: 8m 41s	remaining: 29m 55s
# 45:	learn: 5.3672909	test: 5.4161646	best: 5.4161646 (45)	total: 8m 53s	remaining: 29m 44s
# 46:	learn: 5.3612917	test: 5.4115024	best: 5.4115024 (46)	total: 9m 4s	remaining: 29m 33s
# 47:	learn: 5.3560652	test: 5.4088564	best: 5.4088564 (47)	total: 9m 16s	remaining: 29m 21s
# 48:	learn: 5.3514606	test: 5.4067351	best: 5.4067351 (48)	total: 9m 27s	remaining: 29m 10s
# 49:	learn: 5.3477028	test: 5.4035546	best: 5.4035546 (49)	total: 9m 39s	remaining: 28m 58s
# 50:	learn: 5.3436971	test: 5.4014190	best: 5.4014190 (50)	total: 9m 50s	remaining: 28m 46s
# 51:	learn: 5.3386064	test: 5.3973939	best: 5.3973939 (51)	total: 10m 2s	remaining: 28m 35s
# 52:	learn: 5.3354319	test: 5.3954350	best: 5.3954350 (52)	total: 10m 14s	remaining: 28m 23s
# 53:	learn: 5.3322430	test: 5.3931687	best: 5.3931687 (53)	total: 10m 25s	remaining: 28m 11s
# 54:	learn: 5.3284247	test: 5.3897094	best: 5.3897094 (54)	total: 10m 36s	remaining: 27m 59s
# 55:	learn: 5.3245327	test: 5.3881690	best: 5.3881690 (55)	total: 10m 48s	remaining: 27m 47s
# 56:	learn: 5.3207514	test: 5.3852954	best: 5.3852954 (56)	total: 11m	remaining: 27m 36s
# 57:	learn: 5.3164403	test: 5.3826904	best: 5.3826904 (57)	total: 11m 11s	remaining: 27m 24s
# 58:	learn: 5.3134770	test: 5.3810741	best: 5.3810741 (58)	total: 11m 23s	remaining: 27m 12s
# 59:	learn: 5.3103626	test: 5.3786075	best: 5.3786075 (59)	total: 11m 34s	remaining: 27m 1s
# 60:	learn: 5.3076627	test: 5.3766817	best: 5.3766817 (60)	total: 11m 46s	remaining: 26m 49s
# 61:	learn: 5.3034942	test: 5.3738361	best: 5.3738361 (61)	total: 11m 58s	remaining: 26m 38s
# 62:	learn: 5.3002445	test: 5.3719425	best: 5.3719425 (62)	total: 12m 9s	remaining: 26m 26s
# 63:	learn: 5.2965666	test: 5.3696545	best: 5.3696545 (63)	total: 12m 21s	remaining: 26m 15s
# 64:	learn: 5.2939186	test: 5.3682025	best: 5.3682025 (64)	total: 12m 32s	remaining: 26m 3s
# 65:	learn: 5.2904832	test: 5.3666296	best: 5.3666296 (65)	total: 12m 44s	remaining: 25m 51s
# 66:	learn: 5.2870024	test: 5.3646622	best: 5.3646622 (66)	total: 12m 55s	remaining: 25m 40s
# 67:	learn: 5.2833088	test: 5.3624594	best: 5.3624594 (67)	total: 13m 7s	remaining: 25m 28s
# 68:	learn: 5.2796573	test: 5.3595432	best: 5.3595432 (68)	total: 13m 19s	remaining: 25m 17s
# 69:	learn: 5.2761177	test: 5.3570693	best: 5.3570693 (69)	total: 13m 30s	remaining: 25m 5s
# 70:	learn: 5.2736155	test: 5.3554737	best: 5.3554737 (70)	total: 13m 42s	remaining: 24m 54s
# 71:	learn: 5.2715749	test: 5.3540128	best: 5.3540128 (71)	total: 13m 53s	remaining: 24m 42s
# 72:	learn: 5.2680053	test: 5.3511596	best: 5.3511596 (72)	total: 14m 5s	remaining: 24m 30s
# 73:	learn: 5.2655647	test: 5.3498990	best: 5.3498990 (73)	total: 14m 17s	remaining: 24m 19s
# 74:	learn: 5.2626248	test: 5.3481304	best: 5.3481304 (74)	total: 14m 28s	remaining: 24m 7s
# 75:	learn: 5.2605710	test: 5.3467634	best: 5.3467634 (75)	total: 14m 40s	remaining: 23m 56s
# 76:	learn: 5.2573889	test: 5.3452596	best: 5.3452596 (76)	total: 14m 51s	remaining: 23m 44s
# 77:	learn: 5.2539205	test: 5.3432703	best: 5.3432703 (77)	total: 15m 3s	remaining: 23m 32s
# 78:	learn: 5.2516158	test: 5.3406511	best: 5.3406511 (78)	total: 15m 14s	remaining: 23m 21s
# 79:	learn: 5.2486210	test: 5.3389965	best: 5.3389965 (79)	total: 15m 26s	remaining: 23m 9s
# 80:	learn: 5.2463348	test: 5.3382309	best: 5.3382309 (80)	total: 15m 38s	remaining: 22m 58s
# 81:	learn: 5.2434885	test: 5.3361224	best: 5.3361224 (81)	total: 15m 49s	remaining: 22m 46s
# 82:	learn: 5.2418184	test: 5.3352640	best: 5.3352640 (82)	total: 16m 1s	remaining: 22m 34s
# 83:	learn: 5.2395385	test: 5.3337889	best: 5.3337889 (83)	total: 16m 12s	remaining: 22m 23s
# 84:	learn: 5.2377086	test: 5.3333594	best: 5.3333594 (84)	total: 16m 24s	remaining: 22m 11s
# 85:	learn: 5.2359457	test: 5.3317800	best: 5.3317800 (85)	total: 16m 35s	remaining: 21m 59s
# 86:	learn: 5.2336234	test: 5.3307746	best: 5.3307746 (86)	total: 16m 47s	remaining: 21m 48s
# 87:	learn: 5.2314937	test: 5.3291994	best: 5.3291994 (87)	total: 16m 58s	remaining: 21m 36s
# 88:	learn: 5.2299715	test: 5.3286381	best: 5.3286381 (88)	total: 17m 9s	remaining: 21m 24s
# 89:	learn: 5.2281405	test: 5.3278534	best: 5.3278534 (89)	total: 17m 21s	remaining: 21m 13s
# 90:	learn: 5.2267915	test: 5.3270468	best: 5.3270468 (90)	total: 17m 33s	remaining: 21m 1s
# 91:	learn: 5.2249699	test: 5.3263319	best: 5.3263319 (91)	total: 17m 44s	remaining: 20m 49s
# 92:	learn: 5.2229278	test: 5.3254401	best: 5.3254401 (92)	total: 17m 56s	remaining: 20m 38s
# 93:	learn: 5.2212693	test: 5.3244041	best: 5.3244041 (93)	total: 18m 8s	remaining: 20m 26s
# 94:	learn: 5.2195603	test: 5.3235404	best: 5.3235404 (94)	total: 18m 19s	remaining: 20m 15s
# 95:	learn: 5.2176290	test: 5.3217760	best: 5.3217760 (95)	total: 18m 30s	remaining: 20m 3s
# 96:	learn: 5.2151352	test: 5.3197774	best: 5.3197774 (96)	total: 18m 42s	remaining: 19m 52s
# 97:	learn: 5.2133752	test: 5.3189286	best: 5.3189286 (97)	total: 18m 53s	remaining: 19m 40s
# 98:	learn: 5.2112908	test: 5.3177871	best: 5.3177871 (98)	total: 19m 5s	remaining: 19m 28s
# 99:	learn: 5.2091369	test: 5.3171708	best: 5.3171708 (99)	total: 19m 17s	remaining: 19m 17s
# 100:	learn: 5.2070371	test: 5.3158747	best: 5.3158747 (100)	total: 19m 28s	remaining: 19m 5s
# 101:	learn: 5.2046717	test: 5.3144790	best: 5.3144790 (101)	total: 19m 39s	remaining: 18m 53s
# 102:	learn: 5.2025086	test: 5.3137354	best: 5.3137354 (102)	total: 19m 51s	remaining: 18m 42s
# 103:	learn: 5.2009191	test: 5.3129221	best: 5.3129221 (103)	total: 20m 2s	remaining: 18m 30s
# 104:	learn: 5.1988819	test: 5.3120675	best: 5.3120675 (104)	total: 20m 14s	remaining: 18m 18s
# 105:	learn: 5.1964775	test: 5.3108969	best: 5.3108969 (105)	total: 20m 26s	remaining: 18m 7s
# 106:	learn: 5.1943931	test: 5.3094243	best: 5.3094243 (106)	total: 20m 37s	remaining: 17m 55s
# 107:	learn: 5.1920132	test: 5.3080208	best: 5.3080208 (107)	total: 20m 49s	remaining: 17m 44s
# 108:	learn: 5.1900415	test: 5.3069263	best: 5.3069263 (108)	total: 21m	remaining: 17m 32s
# 109:	learn: 5.1875012	test: 5.3056643	best: 5.3056643 (109)	total: 21m 12s	remaining: 17m 20s
# 110:	learn: 5.1849577	test: 5.3045744	best: 5.3045744 (110)	total: 21m 23s	remaining: 17m 9s
# 111:	learn: 5.1827401	test: 5.3034169	best: 5.3034169 (111)	total: 21m 35s	remaining: 16m 57s
# 112:	learn: 5.1814084	test: 5.3026705	best: 5.3026705 (112)	total: 21m 46s	remaining: 16m 46s
# 113:	learn: 5.1797826	test: 5.3018585	best: 5.3018585 (113)	total: 21m 58s	remaining: 16m 34s
# 114:	learn: 5.1784465	test: 5.3008220	best: 5.3008220 (114)	total: 22m 9s	remaining: 16m 22s
# 115:	learn: 5.1759939	test: 5.2992993	best: 5.2992993 (115)	total: 22m 21s	remaining: 16m 11s
# 116:	learn: 5.1735384	test: 5.2982691	best: 5.2982691 (116)	total: 22m 32s	remaining: 15m 59s
# 117:	learn: 5.1721142	test: 5.2977237	best: 5.2977237 (117)	total: 22m 44s	remaining: 15m 47s
# 118:	learn: 5.1694768	test: 5.2965100	best: 5.2965100 (118)	total: 22m 56s	remaining: 15m 36s
# 119:	learn: 5.1676644	test: 5.2955087	best: 5.2955087 (119)	total: 23m 7s	remaining: 15m 24s
# 120:	learn: 5.1657082	test: 5.2947555	best: 5.2947555 (120)	total: 23m 19s	remaining: 15m 13s
# 121:	learn: 5.1639293	test: 5.2938109	best: 5.2938109 (121)	total: 23m 30s	remaining: 15m 1s
# 122:	learn: 5.1618287	test: 5.2927431	best: 5.2927431 (122)	total: 23m 42s	remaining: 14m 50s
# 123:	learn: 5.1597242	test: 5.2915979	best: 5.2915979 (123)	total: 23m 53s	remaining: 14m 38s
# 124:	learn: 5.1575527	test: 5.2904587	best: 5.2904587 (124)	total: 24m 5s	remaining: 14m 27s
# 125:	learn: 5.1558552	test: 5.2892886	best: 5.2892886 (125)	total: 24m 16s	remaining: 14m 15s
# 126:	learn: 5.1542747	test: 5.2886185	best: 5.2886185 (126)	total: 24m 27s	remaining: 14m 3s
# 127:	learn: 5.1516472	test: 5.2870129	best: 5.2870129 (127)	total: 24m 39s	remaining: 13m 52s
# 128:	learn: 5.1503251	test: 5.2861985	best: 5.2861985 (128)	total: 24m 50s	remaining: 13m 40s
# 129:	learn: 5.1478674	test: 5.2847195	best: 5.2847195 (129)	total: 25m 2s	remaining: 13m 28s
# 130:	learn: 5.1464151	test: 5.2839921	best: 5.2839921 (130)	total: 25m 13s	remaining: 13m 17s
# 131:	learn: 5.1451957	test: 5.2833318	best: 5.2833318 (131)	total: 25m 25s	remaining: 13m 5s
# 132:	learn: 5.1436712	test: 5.2826800	best: 5.2826800 (132)	total: 25m 36s	remaining: 12m 54s
# 133:	learn: 5.1424530	test: 5.2822679	best: 5.2822679 (133)	total: 25m 47s	remaining: 12m 42s
# 134:	learn: 5.1407848	test: 5.2812294	best: 5.2812294 (134)	total: 25m 59s	remaining: 12m 30s
# 135:	learn: 5.1393272	test: 5.2804270	best: 5.2804270 (135)	total: 26m 10s	remaining: 12m 19s
# 136:	learn: 5.1373197	test: 5.2795992	best: 5.2795992 (136)	total: 26m 22s	remaining: 12m 7s
# 137:	learn: 5.1357914	test: 5.2787387	best: 5.2787387 (137)	total: 26m 33s	remaining: 11m 55s
# 138:	learn: 5.1337021	test: 5.2776198	best: 5.2776198 (138)	total: 26m 45s	remaining: 11m 44s
# 139:	learn: 5.1315928	test: 5.2768689	best: 5.2768689 (139)	total: 26m 56s	remaining: 11m 32s
# 140:	learn: 5.1298208	test: 5.2761615	best: 5.2761615 (140)	total: 27m 8s	remaining: 11m 21s
# 141:	learn: 5.1286072	test: 5.2756073	best: 5.2756073 (141)	total: 27m 19s	remaining: 11m 9s
# 142:	learn: 5.1271376	test: 5.2751584	best: 5.2751584 (142)	total: 27m 31s	remaining: 10m 58s
# 143:	learn: 5.1258283	test: 5.2744003	best: 5.2744003 (143)	total: 27m 42s	remaining: 10m 46s
# 144:	learn: 5.1241965	test: 5.2733768	best: 5.2733768 (144)	total: 27m 53s	remaining: 10m 34s
# 145:	learn: 5.1221777	test: 5.2723086	best: 5.2723086 (145)	total: 28m 5s	remaining: 10m 23s
# 146:	learn: 5.1204025	test: 5.2710592	best: 5.2710592 (146)	total: 28m 17s	remaining: 10m 11s
# 147:	learn: 5.1184964	test: 5.2703108	best: 5.2703108 (147)	total: 28m 28s	remaining: 10m
# 148:	learn: 5.1172316	test: 5.2697787	best: 5.2697787 (148)	total: 28m 40s	remaining: 9m 48s
# 149:	learn: 5.1161633	test: 5.2692451	best: 5.2692451 (149)	total: 28m 51s	remaining: 9m 37s
# 150:	learn: 5.1151971	test: 5.2689387	best: 5.2689387 (150)	total: 29m 2s	remaining: 9m 25s
# 151:	learn: 5.1136550	test: 5.2682475	best: 5.2682475 (151)	total: 29m 13s	remaining: 9m 13s
# 152:	learn: 5.1116036	test: 5.2674109	best: 5.2674109 (152)	total: 29m 25s	remaining: 9m 2s
# 153:	learn: 5.1099854	test: 5.2664855	best: 5.2664855 (153)	total: 29m 37s	remaining: 8m 50s
# 154:	learn: 5.1077049	test: 5.2653728	best: 5.2653728 (154)	total: 29m 48s	remaining: 8m 39s
# 155:	learn: 5.1061520	test: 5.2648211	best: 5.2648211 (155)	total: 30m	remaining: 8m 27s
# 156:	learn: 5.1050654	test: 5.2642783	best: 5.2642783 (156)	total: 30m 11s	remaining: 8m 16s
# 157:	learn: 5.1036601	test: 5.2635784	best: 5.2635784 (157)	total: 30m 22s	remaining: 8m 4s
# 158:	learn: 5.1022792	test: 5.2633022	best: 5.2633022 (158)	total: 30m 34s	remaining: 7m 52s
# 159:	learn: 5.1010214	test: 5.2624119	best: 5.2624119 (159)	total: 30m 45s	remaining: 7m 41s
# 160:	learn: 5.0998993	test: 5.2618719	best: 5.2618719 (160)	total: 30m 56s	remaining: 7m 29s
# 161:	learn: 5.0986688	test: 5.2611649	best: 5.2611649 (161)	total: 31m 8s	remaining: 7m 18s
# 162:	learn: 5.0972533	test: 5.2606664	best: 5.2606664 (162)	total: 31m 19s	remaining: 7m 6s
# 163:	learn: 5.0959087	test: 5.2600612	best: 5.2600612 (163)	total: 31m 31s	remaining: 6m 55s
# 164:	learn: 5.0946297	test: 5.2595952	best: 5.2595952 (164)	total: 31m 42s	remaining: 6m 43s
# 165:	learn: 5.0924900	test: 5.2591143	best: 5.2591143 (165)	total: 31m 54s	remaining: 6m 32s
# 166:	learn: 5.0912699	test: 5.2584310	best: 5.2584310 (166)	total: 32m 5s	remaining: 6m 20s
# 167:	learn: 5.0898893	test: 5.2577351	best: 5.2577351 (167)	total: 32m 16s	remaining: 6m 8s
# 168:	learn: 5.0888718	test: 5.2569810	best: 5.2569810 (168)	total: 32m 28s	remaining: 5m 57s
# 169:	learn: 5.0876737	test: 5.2565991	best: 5.2565991 (169)	total: 32m 39s	remaining: 5m 45s
# 170:	learn: 5.0861149	test: 5.2558344	best: 5.2558344 (170)	total: 32m 51s	remaining: 5m 34s
# 171:	learn: 5.0842920	test: 5.2543948	best: 5.2543948 (171)	total: 33m 2s	remaining: 5m 22s
# 172:	learn: 5.0830152	test: 5.2541031	best: 5.2541031 (172)	total: 33m 14s	remaining: 5m 11s
# 173:	learn: 5.0820038	test: 5.2537939	best: 5.2537939 (173)	total: 33m 25s	remaining: 4m 59s
# 174:	learn: 5.0804324	test: 5.2528859	best: 5.2528859 (174)	total: 33m 37s	remaining: 4m 48s
# 175:	learn: 5.0795397	test: 5.2522648	best: 5.2522648 (175)	total: 33m 48s	remaining: 4m 36s
# 176:	learn: 5.0784804	test: 5.2517395	best: 5.2517395 (176)	total: 33m 59s	remaining: 4m 25s
# 177:	learn: 5.0775898	test: 5.2513182	best: 5.2513182 (177)	total: 34m 11s	remaining: 4m 13s
# 178:	learn: 5.0761917	test: 5.2506785	best: 5.2506785 (178)	total: 34m 22s	remaining: 4m 1s
# 179:	learn: 5.0748891	test: 5.2503679	best: 5.2503679 (179)	total: 34m 34s	remaining: 3m 50s
# 180:	learn: 5.0735296	test: 5.2496977	best: 5.2496977 (180)	total: 34m 45s	remaining: 3m 38s
# 181:	learn: 5.0723697	test: 5.2489734	best: 5.2489734 (181)	total: 34m 56s	remaining: 3m 27s
# 182:	learn: 5.0712969	test: 5.2488457	best: 5.2488457 (182)	total: 35m 8s	remaining: 3m 15s
# 183:	learn: 5.0699845	test: 5.2484867	best: 5.2484867 (183)	total: 35m 19s	remaining: 3m 4s
# 184:	learn: 5.0694549	test: 5.2482138	best: 5.2482138 (184)	total: 35m 30s	remaining: 2m 52s
# 185:	learn: 5.0681006	test: 5.2475126	best: 5.2475126 (185)	total: 35m 42s	remaining: 2m 41s
# 186:	learn: 5.0667692	test: 5.2471016	best: 5.2471016 (186)	total: 35m 53s	remaining: 2m 29s
# 187:	learn: 5.0658976	test: 5.2468341	best: 5.2468341 (187)	total: 36m 5s	remaining: 2m 18s
# 188:	learn: 5.0648146	test: 5.2464140	best: 5.2464140 (188)	total: 36m 16s	remaining: 2m 6s
# 189:	learn: 5.0640126	test: 5.2461266	best: 5.2461266 (189)	total: 36m 27s	remaining: 1m 55s
# 190:	learn: 5.0633154	test: 5.2459112	best: 5.2459112 (190)	total: 36m 39s	remaining: 1m 43s
# 191:	learn: 5.0626635	test: 5.2456733	best: 5.2456733 (191)	total: 36m 50s	remaining: 1m 32s
# 192:	learn: 5.0612111	test: 5.2450594	best: 5.2450594 (192)	total: 37m 2s	remaining: 1m 20s
# 193:	learn: 5.0595035	test: 5.2444880	best: 5.2444880 (193)	total: 37m 13s	remaining: 1m 9s
# 194:	learn: 5.0578503	test: 5.2439429	best: 5.2439429 (194)	total: 37m 25s	remaining: 57.6s
# 195:	learn: 5.0567367	test: 5.2432963	best: 5.2432963 (195)	total: 37m 36s	remaining: 46.1s
# 196:	learn: 5.0559804	test: 5.2430436	best: 5.2430436 (196)	total: 37m 47s	remaining: 34.5s
# 197:	learn: 5.0555112	test: 5.2428106	best: 5.2428106 (197)	total: 37m 59s	remaining: 23s
# 198:	learn: 5.0533985	test: 5.2417491	best: 5.2417491 (198)	total: 38m 10s	remaining: 11.5s
# 199:	learn: 5.0529429	test: 5.2414656	best: 5.2414656 (199)	total: 38m 21s	remaining: 0us
#
# bestTest = 5.241465568
# bestIteration = 199
#
# corr =  0.89633
# 0:	learn: 6.8452850	test: 6.7234424	best: 6.7234424 (0)	total: 11.5s	remaining: 38m
# 1:	learn: 6.6789918	test: 6.5855540	best: 6.5855540 (1)	total: 23.1s	remaining: 38m 4s
# 2:	learn: 6.5267036	test: 6.4556127	best: 6.4556127 (2)	total: 34.6s	remaining: 37m 53s
# 3:	learn: 6.4006467	test: 6.3496350	best: 6.3496350 (3)	total: 46.1s	remaining: 37m 40s
# 4:	learn: 6.2923247	test: 6.2592502	best: 6.2592502 (4)	total: 57.7s	remaining: 37m 30s
# 5:	learn: 6.1957841	test: 6.1818282	best: 6.1818282 (5)	total: 1m 9s	remaining: 37m 20s
# 6:	learn: 6.1122534	test: 6.1120403	best: 6.1120403 (6)	total: 1m 20s	remaining: 37m 10s
# 7:	learn: 6.0412599	test: 6.0559971	best: 6.0559971 (7)	total: 1m 32s	remaining: 36m 59s
# 8:	learn: 5.9814606	test: 6.0065120	best: 6.0065120 (8)	total: 1m 44s	remaining: 36m 47s
# 9:	learn: 5.9262232	test: 5.9615633	best: 5.9615633 (9)	total: 1m 55s	remaining: 36m 37s
# 10:	learn: 5.8776893	test: 5.9204304	best: 5.9204304 (10)	total: 2m 7s	remaining: 36m 25s
# 11:	learn: 5.8339123	test: 5.8854378	best: 5.8854378 (11)	total: 2m 18s	remaining: 36m 14s
# 12:	learn: 5.7962557	test: 5.8576952	best: 5.8576952 (12)	total: 2m 30s	remaining: 36m 3s
# 13:	learn: 5.7611112	test: 5.8266219	best: 5.8266219 (13)	total: 2m 42s	remaining: 35m 53s
# 14:	learn: 5.7281369	test: 5.8024127	best: 5.8024127 (14)	total: 2m 53s	remaining: 35m 40s
# 15:	learn: 5.6962482	test: 5.7745978	best: 5.7745978 (15)	total: 3m 5s	remaining: 35m 28s
# 16:	learn: 5.6731835	test: 5.7554756	best: 5.7554756 (16)	total: 3m 16s	remaining: 35m 17s
# 17:	learn: 5.6497374	test: 5.7358385	best: 5.7358385 (17)	total: 3m 28s	remaining: 35m 5s
# 18:	learn: 5.6285989	test: 5.7172025	best: 5.7172025 (18)	total: 3m 39s	remaining: 34m 54s
# 19:	learn: 5.6096452	test: 5.6994678	best: 5.6994678 (19)	total: 3m 51s	remaining: 34m 44s
# 20:	learn: 5.5899101	test: 5.6819180	best: 5.6819180 (20)	total: 4m 3s	remaining: 34m 31s
# 21:	learn: 5.5710722	test: 5.6664874	best: 5.6664874 (21)	total: 4m 14s	remaining: 34m 20s
# 22:	learn: 5.5558955	test: 5.6535111	best: 5.6535111 (22)	total: 4m 26s	remaining: 34m 8s
# 23:	learn: 5.5411668	test: 5.6421381	best: 5.6421381 (23)	total: 4m 37s	remaining: 33m 56s
# 24:	learn: 5.5292380	test: 5.6308916	best: 5.6308916 (24)	total: 4m 49s	remaining: 33m 43s
# 25:	learn: 5.5147107	test: 5.6103467	best: 5.6103467 (25)	total: 5m	remaining: 33m 32s
# 26:	learn: 5.5018229	test: 5.5989772	best: 5.5989772 (26)	total: 5m 12s	remaining: 33m 20s
# 27:	learn: 5.4889274	test: 5.5870576	best: 5.5870576 (27)	total: 5m 23s	remaining: 33m 10s
# 28:	learn: 5.4785362	test: 5.5703191	best: 5.5703191 (28)	total: 5m 35s	remaining: 32m 57s
# 29:	learn: 5.4676456	test: 5.5595189	best: 5.5595189 (29)	total: 5m 46s	remaining: 32m 46s
# 30:	learn: 5.4575619	test: 5.5517670	best: 5.5517670 (30)	total: 5m 58s	remaining: 32m 35s
# 31:	learn: 5.4487552	test: 5.5433770	best: 5.5433770 (31)	total: 6m 10s	remaining: 32m 24s
# 32:	learn: 5.4403360	test: 5.5373733	best: 5.5373733 (32)	total: 6m 21s	remaining: 32m 12s
# 33:	learn: 5.4319586	test: 5.5307223	best: 5.5307223 (33)	total: 6m 33s	remaining: 32m
# 34:	learn: 5.4255553	test: 5.5266730	best: 5.5266730 (34)	total: 6m 44s	remaining: 31m 49s
# 35:	learn: 5.4188014	test: 5.5217753	best: 5.5217753 (35)	total: 6m 56s	remaining: 31m 37s
# 36:	learn: 5.4095621	test: 5.5140263	best: 5.5140263 (36)	total: 7m 8s	remaining: 31m 26s
# 37:	learn: 5.4023507	test: 5.5077400	best: 5.5077400 (37)	total: 7m 19s	remaining: 31m 14s
# 38:	learn: 5.3951043	test: 5.5023086	best: 5.5023086 (38)	total: 7m 31s	remaining: 31m 3s
# 39:	learn: 5.3893691	test: 5.4963031	best: 5.4963031 (39)	total: 7m 42s	remaining: 30m 51s
# 40:	learn: 5.3840052	test: 5.4874405	best: 5.4874405 (40)	total: 7m 54s	remaining: 30m 39s
# 41:	learn: 5.3779537	test: 5.4828584	best: 5.4828584 (41)	total: 8m 5s	remaining: 30m 27s
# 42:	learn: 5.3716681	test: 5.4783497	best: 5.4783497 (42)	total: 8m 17s	remaining: 30m 17s
# 43:	learn: 5.3672845	test: 5.4746090	best: 5.4746090 (43)	total: 8m 29s	remaining: 30m 5s
# 44:	learn: 5.3621655	test: 5.4705866	best: 5.4705866 (44)	total: 8m 40s	remaining: 29m 53s
# 45:	learn: 5.3561273	test: 5.4619386	best: 5.4619386 (45)	total: 8m 52s	remaining: 29m 41s
# 46:	learn: 5.3505533	test: 5.4585759	best: 5.4585759 (46)	total: 9m 3s	remaining: 29m 30s
# 47:	learn: 5.3462412	test: 5.4558405	best: 5.4558405 (47)	total: 9m 15s	remaining: 29m 18s
# 48:	learn: 5.3406316	test: 5.4512493	best: 5.4512493 (48)	total: 9m 26s	remaining: 29m 7s
# 49:	learn: 5.3360565	test: 5.4486184	best: 5.4486184 (49)	total: 9m 38s	remaining: 28m 55s
# 50:	learn: 5.3317047	test: 5.4427829	best: 5.4427829 (50)	total: 9m 50s	remaining: 28m 44s
# 51:	learn: 5.3281540	test: 5.4392974	best: 5.4392974 (51)	total: 10m 1s	remaining: 28m 32s
# 52:	learn: 5.3244077	test: 5.4365342	best: 5.4365342 (52)	total: 10m 13s	remaining: 28m 21s
# 53:	learn: 5.3206930	test: 5.4324985	best: 5.4324985 (53)	total: 10m 24s	remaining: 28m 9s
# 54:	learn: 5.3155939	test: 5.4271912	best: 5.4271912 (54)	total: 10m 36s	remaining: 27m 57s
# 55:	learn: 5.3135879	test: 5.4250570	best: 5.4250570 (55)	total: 10m 47s	remaining: 27m 45s
# 56:	learn: 5.3097946	test: 5.4221459	best: 5.4221459 (56)	total: 10m 59s	remaining: 27m 34s
# 57:	learn: 5.3074673	test: 5.4209403	best: 5.4209403 (57)	total: 11m 10s	remaining: 27m 22s
# 58:	learn: 5.3034780	test: 5.4168110	best: 5.4168110 (58)	total: 11m 22s	remaining: 27m 10s
# 59:	learn: 5.3003141	test: 5.4148718	best: 5.4148718 (59)	total: 11m 33s	remaining: 26m 58s
# 60:	learn: 5.2966789	test: 5.4110490	best: 5.4110490 (60)	total: 11m 45s	remaining: 26m 47s
# 61:	learn: 5.2934374	test: 5.4089821	best: 5.4089821 (61)	total: 11m 56s	remaining: 26m 35s
# 62:	learn: 5.2892199	test: 5.4056010	best: 5.4056010 (62)	total: 12m 8s	remaining: 26m 24s
# 63:	learn: 5.2867080	test: 5.4039112	best: 5.4039112 (63)	total: 12m 20s	remaining: 26m 12s
# 64:	learn: 5.2842408	test: 5.4019964	best: 5.4019964 (64)	total: 12m 31s	remaining: 26m
# 65:	learn: 5.2813407	test: 5.4006444	best: 5.4006444 (65)	total: 12m 43s	remaining: 25m 49s
# 66:	learn: 5.2793014	test: 5.3995077	best: 5.3995077 (66)	total: 12m 54s	remaining: 25m 37s
# 67:	learn: 5.2766556	test: 5.3976794	best: 5.3976794 (67)	total: 13m 6s	remaining: 25m 26s
# 68:	learn: 5.2741872	test: 5.3961033	best: 5.3961033 (68)	total: 13m 17s	remaining: 25m 14s
# 69:	learn: 5.2714166	test: 5.3938613	best: 5.3938613 (69)	total: 13m 29s	remaining: 25m 2s
# 70:	learn: 5.2685217	test: 5.3920489	best: 5.3920489 (70)	total: 13m 40s	remaining: 24m 51s
# 71:	learn: 5.2660415	test: 5.3901393	best: 5.3901393 (71)	total: 13m 52s	remaining: 24m 39s
# 72:	learn: 5.2633787	test: 5.3875624	best: 5.3875624 (72)	total: 14m 3s	remaining: 24m 28s
# 73:	learn: 5.2600875	test: 5.3838005	best: 5.3838005 (73)	total: 14m 15s	remaining: 24m 16s
# 74:	learn: 5.2579032	test: 5.3826939	best: 5.3826939 (74)	total: 14m 26s	remaining: 24m 4s
# 75:	learn: 5.2556855	test: 5.3809247	best: 5.3809247 (75)	total: 14m 38s	remaining: 23m 53s
# 76:	learn: 5.2537412	test: 5.3800405	best: 5.3800405 (76)	total: 14m 49s	remaining: 23m 41s
# 77:	learn: 5.2515982	test: 5.3787997	best: 5.3787997 (77)	total: 15m 1s	remaining: 23m 30s
# 78:	learn: 5.2491156	test: 5.3769380	best: 5.3769380 (78)	total: 15m 13s	remaining: 23m 18s
# 79:	learn: 5.2469636	test: 5.3758556	best: 5.3758556 (79)	total: 15m 24s	remaining: 23m 7s
# 80:	learn: 5.2450641	test: 5.3746642	best: 5.3746642 (80)	total: 15m 36s	remaining: 22m 55s
# 81:	learn: 5.2423595	test: 5.3731451	best: 5.3731451 (81)	total: 15m 47s	remaining: 22m 43s
# 82:	learn: 5.2394501	test: 5.3710119	best: 5.3710119 (82)	total: 15m 59s	remaining: 22m 32s
# 83:	learn: 5.2365161	test: 5.3688431	best: 5.3688431 (83)	total: 16m 10s	remaining: 22m 20s
# 84:	learn: 5.2341875	test: 5.3677469	best: 5.3677469 (84)	total: 16m 22s	remaining: 22m 9s
# 85:	learn: 5.2320838	test: 5.3663813	best: 5.3663813 (85)	total: 16m 33s	remaining: 21m 57s
# 86:	learn: 5.2304137	test: 5.3652289	best: 5.3652289 (86)	total: 16m 45s	remaining: 21m 45s
# 87:	learn: 5.2281297	test: 5.3636660	best: 5.3636660 (87)	total: 16m 56s	remaining: 21m 34s
# 88:	learn: 5.2260263	test: 5.3623558	best: 5.3623558 (88)	total: 17m 8s	remaining: 21m 22s
# 89:	learn: 5.2237954	test: 5.3608268	best: 5.3608268 (89)	total: 17m 20s	remaining: 21m 11s
# 90:	learn: 5.2215645	test: 5.3597628	best: 5.3597628 (90)	total: 17m 31s	remaining: 20m 59s
# 91:	learn: 5.2192356	test: 5.3581846	best: 5.3581846 (91)	total: 17m 43s	remaining: 20m 47s
# 92:	learn: 5.2175133	test: 5.3569373	best: 5.3569373 (92)	total: 17m 54s	remaining: 20m 36s
# 93:	learn: 5.2152142	test: 5.3553933	best: 5.3553933 (93)	total: 18m 6s	remaining: 20m 24s
# 94:	learn: 5.2142155	test: 5.3548790	best: 5.3548790 (94)	total: 18m 17s	remaining: 20m 12s
# 95:	learn: 5.2123001	test: 5.3541067	best: 5.3541067 (95)	total: 18m 28s	remaining: 20m 1s
# 96:	learn: 5.2100601	test: 5.3532900	best: 5.3532900 (96)	total: 18m 40s	remaining: 19m 49s
# 97:	learn: 5.2079759	test: 5.3514388	best: 5.3514388 (97)	total: 18m 51s	remaining: 19m 38s
# 98:	learn: 5.2056772	test: 5.3502534	best: 5.3502534 (98)	total: 19m 3s	remaining: 19m 26s
# 99:	learn: 5.2042610	test: 5.3495067	best: 5.3495067 (99)	total: 19m 14s	remaining: 19m 14s
# 100:	learn: 5.2019067	test: 5.3481250	best: 5.3481250 (100)	total: 19m 26s	remaining: 19m 3s
# 101:	learn: 5.1998021	test: 5.3468258	best: 5.3468258 (101)	total: 19m 38s	remaining: 18m 52s
# 102:	learn: 5.1975972	test: 5.3461588	best: 5.3461588 (102)	total: 19m 49s	remaining: 18m 40s
# 103:	learn: 5.1957054	test: 5.3441222	best: 5.3441222 (103)	total: 20m 1s	remaining: 18m 28s
# 104:	learn: 5.1933045	test: 5.3430866	best: 5.3430866 (104)	total: 20m 12s	remaining: 18m 17s
# 105:	learn: 5.1914217	test: 5.3424413	best: 5.3424413 (105)	total: 20m 24s	remaining: 18m 5s
# 106:	learn: 5.1892127	test: 5.3406916	best: 5.3406916 (106)	total: 20m 35s	remaining: 17m 53s
# 107:	learn: 5.1866533	test: 5.3378139	best: 5.3378139 (107)	total: 20m 47s	remaining: 17m 42s
# 108:	learn: 5.1849237	test: 5.3368362	best: 5.3368362 (108)	total: 20m 58s	remaining: 17m 30s
# 109:	learn: 5.1829807	test: 5.3357380	best: 5.3357380 (109)	total: 21m 10s	remaining: 17m 19s
# 110:	learn: 5.1802698	test: 5.3340942	best: 5.3340942 (110)	total: 21m 21s	remaining: 17m 7s
# 111:	learn: 5.1781653	test: 5.3330289	best: 5.3330289 (111)	total: 21m 33s	remaining: 16m 55s
# 112:	learn: 5.1763125	test: 5.3321461	best: 5.3321461 (112)	total: 21m 44s	remaining: 16m 44s
# 113:	learn: 5.1751165	test: 5.3305068	best: 5.3305068 (113)	total: 21m 56s	remaining: 16m 32s
# 114:	learn: 5.1734605	test: 5.3293797	best: 5.3293797 (114)	total: 22m 7s	remaining: 16m 21s
# 115:	learn: 5.1717307	test: 5.3283450	best: 5.3283450 (115)	total: 22m 18s	remaining: 16m 9s
# 116:	learn: 5.1694411	test: 5.3267101	best: 5.3267101 (116)	total: 22m 30s	remaining: 15m 57s
# 117:	learn: 5.1671824	test: 5.3255987	best: 5.3255987 (117)	total: 22m 41s	remaining: 15m 46s
# 118:	learn: 5.1655787	test: 5.3247627	best: 5.3247627 (118)	total: 22m 53s	remaining: 15m 34s
# 119:	learn: 5.1641178	test: 5.3239154	best: 5.3239154 (119)	total: 23m 4s	remaining: 15m 22s
# 120:	learn: 5.1627160	test: 5.3232096	best: 5.3232096 (120)	total: 23m 15s	remaining: 15m 11s
# ...
# 31:	learn: 5.3800598	test: 5.8647833	best: 5.8647833 (31)	total: 6m 10s	remaining: 32m 25s
# 32:	learn: 5.3702338	test: 5.8589750	best: 5.8589750 (32)	total: 6m 22s	remaining: 32m 13s
# 33:	learn: 5.3608954	test: 5.8485483	best: 5.8485483 (33)	total: 6m 33s	remaining: 32m 1s
# 34:	learn: 5.3527995	test: 5.8433542	best: 5.8433542 (34)	total: 6m 45s	remaining: 31m 49s
# 35:	learn: 5.3437401	test: 5.8372023	best: 5.8372023 (35)	total: 6m 56s	remaining: 31m 38s
# 36:	learn: 5.3374190	test: 5.8323349	best: 5.8323349 (36)	total: 7m 8s	remaining: 31m 26s
# 37:	learn: 5.3301810	test: 5.8266197	best: 5.8266197 (37)	total: 7m 19s	remaining: 31m 14s
# 38:	learn: 5.3245205	test: 5.8230593	best: 5.8230593 (38)	total: 7m 31s	remaining: 31m 2s
# 39:	learn: 5.3171270	test: 5.8154853	best: 5.8154853 (39)	total: 7m 42s	remaining: 30m 51s
# 40:	learn: 5.3112308	test: 5.8115427	best: 5.8115427 (40)	total: 7m 54s	remaining: 30m 39s
# 41:	learn: 5.3059340	test: 5.8065251	best: 5.8065251 (41)	total: 8m 5s	remaining: 30m 27s
# 42:	learn: 5.3011953	test: 5.8019198	best: 5.8019198 (42)	total: 8m 17s	remaining: 30m 15s
# 43:	learn: 5.2951457	test: 5.7971110	best: 5.7971110 (43)	total: 8m 28s	remaining: 30m 4s
# 44:	learn: 5.2900086	test: 5.7908493	best: 5.7908493 (44)	total: 8m 40s	remaining: 29m 52s
# 45:	learn: 5.2848679	test: 5.7872823	best: 5.7872823 (45)	total: 8m 52s	remaining: 29m 41s
# 46:	learn: 5.2799910	test: 5.7818135	best: 5.7818135 (46)	total: 9m 3s	remaining: 29m 29s
# 47:	learn: 5.2754148	test: 5.7775863	best: 5.7775863 (47)	total: 9m 14s	remaining: 29m 17s
# 48:	learn: 5.2703782	test: 5.7721477	best: 5.7721477 (48)	total: 9m 26s	remaining: 29m 5s
# 49:	learn: 5.2667369	test: 5.7689058	best: 5.7689058 (49)	total: 9m 37s	remaining: 28m 53s
# 50:	learn: 5.2626820	test: 5.7649627	best: 5.7649627 (50)	total: 9m 49s	remaining: 28m 41s
# 51:	learn: 5.2587264	test: 5.7622871	best: 5.7622871 (51)	total: 10m	remaining: 28m 30s
# 52:	learn: 5.2547594	test: 5.7586291	best: 5.7586291 (52)	total: 10m 12s	remaining: 28m 18s
# 53:	learn: 5.2504069	test: 5.7558304	best: 5.7558304 (53)	total: 10m 23s	remaining: 28m 6s
# 54:	learn: 5.2468622	test: 5.7529861	best: 5.7529861 (54)	total: 10m 35s	remaining: 27m 55s
# 55:	learn: 5.2438528	test: 5.7510978	best: 5.7510978 (55)	total: 10m 46s	remaining: 27m 43s
# 56:	learn: 5.2413484	test: 5.7491215	best: 5.7491215 (56)	total: 10m 58s	remaining: 27m 31s
# 57:	learn: 5.2364735	test: 5.7468995	best: 5.7468995 (57)	total: 11m 9s	remaining: 27m 20s
# 58:	learn: 5.2331310	test: 5.7442388	best: 5.7442388 (58)	total: 11m 21s	remaining: 27m 8s
# 59:	learn: 5.2298887	test: 5.7426082	best: 5.7426082 (59)	total: 11m 32s	remaining: 26m 56s
# 60:	learn: 5.2253869	test: 5.7384897	best: 5.7384897 (60)	total: 11m 44s	remaining: 26m 45s
# 61:	learn: 5.2231142	test: 5.7371930	best: 5.7371930 (61)	total: 11m 55s	remaining: 26m 33s
# 62:	learn: 5.2189275	test: 5.7354288	best: 5.7354288 (62)	total: 12m 7s	remaining: 26m 22s
# 63:	learn: 5.2158805	test: 5.7324340	best: 5.7324340 (63)	total: 12m 19s	remaining: 26m 10s
# 64:	learn: 5.2135195	test: 5.7309854	best: 5.7309854 (64)	total: 12m 30s	remaining: 25m 58s
# 65:	learn: 5.2100052	test: 5.7293635	best: 5.7293635 (65)	total: 12m 42s	remaining: 25m 47s
# 66:	learn: 5.2077602	test: 5.7274999	best: 5.7274999 (66)	total: 12m 53s	remaining: 25m 36s
# 67:	learn: 5.2046950	test: 5.7256007	best: 5.7256007 (67)	total: 13m 5s	remaining: 25m 24s
# 68:	learn: 5.2014380	test: 5.7242245	best: 5.7242245 (68)	total: 13m 17s	remaining: 25m 13s
# 69:	learn: 5.1998236	test: 5.7229962	best: 5.7229962 (69)	total: 13m 28s	remaining: 25m 1s
# 70:	learn: 5.1966105	test: 5.7214461	best: 5.7214461 (70)	total: 13m 40s	remaining: 24m 50s
# 71:	learn: 5.1939885	test: 5.7188889	best: 5.7188889 (71)	total: 13m 51s	remaining: 24m 38s
# 72:	learn: 5.1914875	test: 5.7171127	best: 5.7171127 (72)	total: 14m 3s	remaining: 24m 27s
# 73:	learn: 5.1887130	test: 5.7152348	best: 5.7152348 (73)	total: 14m 15s	remaining: 24m 15s
# 74:	learn: 5.1863298	test: 5.7136105	best: 5.7136105 (74)	total: 14m 26s	remaining: 24m 4s
# 75:	learn: 5.1838977	test: 5.7119293	best: 5.7119293 (75)	total: 14m 38s	remaining: 23m 53s
# 76:	learn: 5.1815866	test: 5.7104812	best: 5.7104812 (76)	total: 14m 49s	remaining: 23m 41s
# 77:	learn: 5.1793694	test: 5.7087314	best: 5.7087314 (77)	total: 15m 1s	remaining: 23m 29s
# 78:	learn: 5.1764719	test: 5.7064177	best: 5.7064177 (78)	total: 15m 12s	remaining: 23m 18s
# 79:	learn: 5.1740363	test: 5.7045788	best: 5.7045788 (79)	total: 15m 24s	remaining: 23m 6s
# 80:	learn: 5.1718341	test: 5.7028121	best: 5.7028121 (80)	total: 15m 35s	remaining: 22m 55s
# 81:	learn: 5.1700734	test: 5.7015638	best: 5.7015638 (81)	total: 15m 47s	remaining: 22m 43s
# 82:	learn: 5.1678558	test: 5.6988126	best: 5.6988126 (82)	total: 15m 58s	remaining: 22m 31s
# 83:	learn: 5.1660580	test: 5.6975077	best: 5.6975077 (83)	total: 16m 10s	remaining: 22m 20s
# 84:	learn: 5.1642143	test: 5.6966759	best: 5.6966759 (84)	total: 16m 22s	remaining: 22m 8s
# 85:	learn: 5.1613022	test: 5.6954143	best: 5.6954143 (85)	total: 16m 33s	remaining: 21m 57s
# 86:	learn: 5.1586846	test: 5.6933833	best: 5.6933833 (86)	total: 16m 45s	remaining: 21m 45s
# 87:	learn: 5.1569208	test: 5.6923969	best: 5.6923969 (87)	total: 16m 56s	remaining: 21m 34s
# 88:	learn: 5.1551840	test: 5.6905743	best: 5.6905743 (88)	total: 17m 8s	remaining: 21m 22s
# 89:	learn: 5.1536828	test: 5.6894642	best: 5.6894642 (89)	total: 17m 19s	remaining: 21m 10s
# 90:	learn: 5.1508093	test: 5.6875919	best: 5.6875919 (90)	total: 17m 31s	remaining: 20m 59s
# 91:	learn: 5.1488536	test: 5.6865896	best: 5.6865896 (91)	total: 17m 42s	remaining: 20m 47s
# 92:	learn: 5.1466555	test: 5.6849131	best: 5.6849131 (92)	total: 17m 54s	remaining: 20m 36s
# 93:	learn: 5.1441693	test: 5.6830685	best: 5.6830685 (93)	total: 18m 6s	remaining: 20m 24s
# 94:	learn: 5.1425745	test: 5.6824641	best: 5.6824641 (94)	total: 18m 17s	remaining: 20m 13s
# 95:	learn: 5.1403212	test: 5.6811013	best: 5.6811013 (95)	total: 18m 29s	remaining: 20m 1s
# 96:	learn: 5.1382942	test: 5.6797579	best: 5.6797579 (96)	total: 18m 40s	remaining: 19m 49s
# 97:	learn: 5.1366483	test: 5.6787796	best: 5.6787796 (97)	total: 18m 52s	remaining: 19m 38s
# 98:	learn: 5.1347596	test: 5.6781607	best: 5.6781607 (98)	total: 19m 3s	remaining: 19m 26s
# 99:	learn: 5.1329371	test: 5.6774279	best: 5.6774279 (99)	total: 19m 15s	remaining: 19m 15s
# 100:	learn: 5.1308333	test: 5.6763718	best: 5.6763718 (100)	total: 19m 26s	remaining: 19m 3s
# 101:	learn: 5.1288608	test: 5.6750152	best: 5.6750152 (101)	total: 19m 38s	remaining: 18m 52s
# 102:	learn: 5.1277704	test: 5.6747663	best: 5.6747663 (102)	total: 19m 49s	remaining: 18m 40s
# 103:	learn: 5.1257473	test: 5.6726897	best: 5.6726897 (103)	total: 20m 1s	remaining: 18m 29s
# 104:	learn: 5.1241495	test: 5.6719619	best: 5.6719619 (104)	total: 20m 12s	remaining: 18m 17s
# 105:	learn: 5.1221466	test: 5.6712038	best: 5.6712038 (105)	total: 20m 24s	remaining: 18m 5s
# 106:	learn: 5.1203463	test: 5.6699498	best: 5.6699498 (106)	total: 20m 36s	remaining: 17m 54s
# 107:	learn: 5.1189429	test: 5.6692697	best: 5.6692697 (107)	total: 20m 47s	remaining: 17m 42s
# 108:	learn: 5.1172974	test: 5.6684151	best: 5.6684151 (108)	total: 20m 58s	remaining: 17m 30s
# 109:	learn: 5.1154345	test: 5.6674354	best: 5.6674354 (109)	total: 21m 10s	remaining: 17m 19s
# 110:	learn: 5.1130767	test: 5.6662776	best: 5.6662776 (110)	total: 21m 21s	remaining: 17m 7s
# 111:	learn: 5.1114299	test: 5.6651789	best: 5.6651789 (111)	total: 21m 33s	remaining: 16m 56s
# 112:	learn: 5.1091767	test: 5.6636154	best: 5.6636154 (112)	total: 21m 45s	remaining: 16m 44s
# 113:	learn: 5.1065143	test: 5.6614053	best: 5.6614053 (113)	total: 21m 56s	remaining: 16m 33s
# 114:	learn: 5.1039051	test: 5.6596077	best: 5.6596077 (114)	total: 22m 8s	remaining: 16m 21s
# 115:	learn: 5.1017295	test: 5.6581029	best: 5.6581029 (115)	total: 22m 19s	remaining: 16m 10s
# 116:	learn: 5.0998880	test: 5.6567329	best: 5.6567329 (116)	total: 22m 31s	remaining: 15m 58s
# 117:	learn: 5.0978253	test: 5.6552238	best: 5.6552238 (117)	total: 22m 42s	remaining: 15m 46s
# 118:	learn: 5.0959781	test: 5.6537671	best: 5.6537671 (118)	total: 22m 53s	remaining: 15m 35s
# 119:	learn: 5.0943135	test: 5.6522489	best: 5.6522489 (119)	total: 23m 5s	remaining: 15m 23s
# 120:	learn: 5.0919018	test: 5.6503329	best: 5.6503329 (120)	total: 23m 16s	remaining: 15m 11s
# 121:	learn: 5.0894897	test: 5.6492620	best: 5.6492620 (121)	total: 23m 28s	remaining: 15m
# 122:	learn: 5.0878878	test: 5.6481580	best: 5.6481580 (122)	total: 23m 39s	remaining: 14m 48s
# 123:	learn: 5.0863995	test: 5.6468802	best: 5.6468802 (123)	total: 23m 51s	remaining: 14m 37s
# 124:	learn: 5.0841018	test: 5.6450258	best: 5.6450258 (124)	total: 24m 2s	remaining: 14m 25s
# 125:	learn: 5.0823626	test: 5.6441389	best: 5.6441389 (125)	total: 24m 14s	remaining: 14m 13s
# 126:	learn: 5.0804701	test: 5.6423020	best: 5.6423020 (126)	total: 24m 25s	remaining: 14m 2s
# 127:	learn: 5.0788862	test: 5.6410936	best: 5.6410936 (127)	total: 24m 36s	remaining: 13m 50s
# 128:	learn: 5.0772478	test: 5.6399723	best: 5.6399723 (128)	total: 24m 48s	remaining: 13m 39s
# 129:	learn: 5.0757920	test: 5.6387165	best: 5.6387165 (129)	total: 24m 59s	remaining: 13m 27s
# 130:	learn: 5.0742714	test: 5.6376991	best: 5.6376991 (130)	total: 25m 11s	remaining: 13m 15s
# 131:	learn: 5.0722061	test: 5.6365062	best: 5.6365062 (131)	total: 25m 22s	remaining: 13m 4s
# 132:	learn: 5.0698268	test: 5.6341968	best: 5.6341968 (132)	total: 25m 34s	remaining: 12m 52s
# 133:	learn: 5.0677171	test: 5.6328141	best: 5.6328141 (133)	total: 25m 45s	remaining: 12m 41s
# 134:	learn: 5.0663663	test: 5.6316067	best: 5.6316067 (134)	total: 25m 57s	remaining: 12m 29s
# 135:	learn: 5.0646306	test: 5.6309708	best: 5.6309708 (135)	total: 26m 8s	remaining: 12m 18s
# 136:	learn: 5.0627215	test: 5.6292977	best: 5.6292977 (136)	total: 26m 20s	remaining: 12m 6s
# 137:	learn: 5.0617747	test: 5.6289362	best: 5.6289362 (137)	total: 26m 31s	remaining: 11m 54s
# 138:	learn: 5.0597981	test: 5.6276178	best: 5.6276178 (138)	total: 26m 42s	remaining: 11m 43s
# 139:	learn: 5.0583546	test: 5.6270876	best: 5.6270876 (139)	total: 26m 54s	remaining: 11m 31s
# 140:	learn: 5.0567418	test: 5.6258898	best: 5.6258898 (140)	total: 27m 5s	remaining: 11m 20s
# 141:	learn: 5.0550291	test: 5.6244727	best: 5.6244727 (141)	total: 27m 17s	remaining: 11m 8s
# 142:	learn: 5.0532593	test: 5.6235884	best: 5.6235884 (142)	total: 27m 28s	remaining: 10m 57s
# 143:	learn: 5.0518542	test: 5.6226629	best: 5.6226629 (143)	total: 27m 40s	remaining: 10m 45s
# 144:	learn: 5.0501270	test: 5.6214545	best: 5.6214545 (144)	total: 27m 51s	remaining: 10m 34s
# 145:	learn: 5.0481750	test: 5.6202038	best: 5.6202038 (145)	total: 28m 3s	remaining: 10m 22s
# 146:	learn: 5.0470339	test: 5.6195049	best: 5.6195049 (146)	total: 28m 14s	remaining: 10m 10s
# 147:	learn: 5.0453332	test: 5.6187185	best: 5.6187185 (147)	total: 28m 25s	remaining: 9m 59s
# 148:	learn: 5.0434503	test: 5.6173229	best: 5.6173229 (148)	total: 28m 37s	remaining: 9m 47s
# 149:	learn: 5.0424820	test: 5.6165379	best: 5.6165379 (149)	total: 28m 48s	remaining: 9m 36s
# 150:	learn: 5.0410742	test: 5.6151881	best: 5.6151881 (150)	total: 28m 59s	remaining: 9m 24s
# 151:	learn: 5.0391662	test: 5.6139996	best: 5.6139996 (151)	total: 29m 11s	remaining: 9m 13s
# 152:	learn: 5.0377980	test: 5.6136413	best: 5.6136413 (152)	total: 29m 22s	remaining: 9m 1s
# 153:	learn: 5.0367046	test: 5.6129610	best: 5.6129610 (153)	total: 29m 33s	remaining: 8m 49s
# 154:	learn: 5.0347720	test: 5.6119096	best: 5.6119096 (154)	total: 29m 45s	remaining: 8m 38s
# 155:	learn: 5.0334394	test: 5.6113518	best: 5.6113518 (155)	total: 29m 56s	remaining: 8m 26s
# 156:	learn: 5.0328120	test: 5.6108864	best: 5.6108864 (156)	total: 30m 7s	remaining: 8m 15s
# 157:	learn: 5.0318121	test: 5.6098431	best: 5.6098431 (157)	total: 30m 19s	remaining: 8m 3s
# 158:	learn: 5.0304786	test: 5.6086762	best: 5.6086762 (158)	total: 30m 30s	remaining: 7m 52s
# 159:	learn: 5.0293917	test: 5.6079838	best: 5.6079838 (159)	total: 30m 41s	remaining: 7m 40s
# 160:	learn: 5.0284223	test: 5.6075916	best: 5.6075916 (160)	total: 30m 52s	remaining: 7m 28s
# 161:	learn: 5.0269922	test: 5.6069650	best: 5.6069650 (161)	total: 31m 4s	remaining: 7m 17s
# 162:	learn: 5.0256366	test: 5.6063146	best: 5.6063146 (162)	total: 31m 15s	remaining: 7m 5s
# 163:	learn: 5.0240925	test: 5.6052424	best: 5.6052424 (163)	total: 31m 27s	remaining: 6m 54s
# 164:	learn: 5.0227347	test: 5.6040652	best: 5.6040652 (164)	total: 31m 38s	remaining: 6m 42s
# 165:	learn: 5.0221255	test: 5.6036681	best: 5.6036681 (165)	total: 31m 49s	remaining: 6m 31s
# 166:	learn: 5.0208790	test: 5.6031597	best: 5.6031597 (166)	total: 32m 1s	remaining: 6m 19s
# 167:	learn: 5.0194871	test: 5.6024549	best: 5.6024549 (167)	total: 32m 12s	remaining: 6m 8s
# 168:	learn: 5.0184177	test: 5.6016665	best: 5.6016665 (168)	total: 32m 23s	remaining: 5m 56s
# 169:	learn: 5.0174810	test: 5.6014106	best: 5.6014106 (169)	total: 32m 35s	remaining: 5m 45s
# 170:	learn: 5.0162847	test: 5.6009935	best: 5.6009935 (170)	total: 32m 46s	remaining: 5m 33s
# 171:	learn: 5.0150542	test: 5.6003141	best: 5.6003141 (171)	total: 32m 58s	remaining: 5m 22s
# 172:	learn: 5.0139044	test: 5.5996477	best: 5.5996477 (172)	total: 33m 9s	remaining: 5m 10s
# 173:	learn: 5.0129876	test: 5.5990244	best: 5.5990244 (173)	total: 33m 20s	remaining: 4m 58s
# 174:	learn: 5.0114472	test: 5.5978588	best: 5.5978588 (174)	total: 33m 32s	remaining: 4m 47s
# 175:	learn: 5.0108071	test: 5.5976620	best: 5.5976620 (175)	total: 33m 43s	remaining: 4m 35s
# 176:	learn: 5.0099259	test: 5.5974594	best: 5.5974594 (176)	total: 33m 54s	remaining: 4m 24s
# 177:	learn: 5.0085993	test: 5.5969250	best: 5.5969250 (177)	total: 34m 5s	remaining: 4m 12s
# 178:	learn: 5.0074376	test: 5.5962670	best: 5.5962670 (178)	total: 34m 17s	remaining: 4m 1s
# 179:	learn: 5.0066253	test: 5.5960343	best: 5.5960343 (179)	total: 34m 28s	remaining: 3m 49s
# 180:	learn: 5.0051955	test: 5.5954815	best: 5.5954815 (180)	total: 34m 40s	remaining: 3m 38s
# 181:	learn: 5.0042114	test: 5.5947298	best: 5.5947298 (181)	total: 34m 51s	remaining: 3m 26s
# 182:	learn: 5.0036288	test: 5.5945297	best: 5.5945297 (182)	total: 35m 2s	remaining: 3m 15s
# 183:	learn: 5.0023484	test: 5.5940871	best: 5.5940871 (183)	total: 35m 13s	remaining: 3m 3s
# 184:	learn: 5.0005818	test: 5.5924694	best: 5.5924694 (184)	total: 35m 25s	remaining: 2m 52s
# 185:	learn: 4.9996961	test: 5.5921486	best: 5.5921486 (185)	total: 35m 36s	remaining: 2m 40s
# 186:	learn: 4.9983501	test: 5.5917587	best: 5.5917587 (186)	total: 35m 48s	remaining: 2m 29s
# 187:	learn: 4.9975798	test: 5.5913247	best: 5.5913247 (187)	total: 35m 59s	remaining: 2m 17s
# 188:	learn: 4.9960572	test: 5.5906821	best: 5.5906821 (188)	total: 36m 10s	remaining: 2m 6s
# 189:	learn: 4.9949268	test: 5.5899637	best: 5.5899637 (189)	total: 36m 22s	remaining: 1m 54s
# 190:	learn: 4.9943510	test: 5.5895812	best: 5.5895812 (190)	total: 36m 33s	remaining: 1m 43s
# 191:	learn: 4.9934849	test: 5.5891008	best: 5.5891008 (191)	total: 36m 44s	remaining: 1m 31s
# 192:	learn: 4.9924168	test: 5.5885112	best: 5.5885112 (192)	total: 36m 55s	remaining: 1m 20s
# 193:	learn: 4.9911944	test: 5.5882775	best: 5.5882775 (193)	total: 37m 6s	remaining: 1m 8s
# 194:	learn: 4.9899009	test: 5.5877816	best: 5.5877816 (194)	total: 37m 18s	remaining: 57.4s
# 195:	learn: 4.9886778	test: 5.5876082	best: 5.5876082 (195)	total: 37m 29s	remaining: 45.9s
# 196:	learn: 4.9878750	test: 5.5872021	best: 5.5872021 (196)	total: 37m 41s	remaining: 34.4s
# 197:	learn: 4.9868425	test: 5.5865331	best: 5.5865331 (197)	total: 37m 52s	remaining: 23s
# 198:	learn: 4.9859340	test: 5.5861289	best: 5.5861289 (198)	total: 38m 3s	remaining: 11.5s
# 199:	learn: 4.9843432	test: 5.5846664	best: 5.5846664 (199)	total: 38m 15s	remaining: 0us
#
# bestTest = 5.584666421
# bestIteration = 199
#
# corr =  0.88110
# Average  corr = nan
# Wall time: 3h 12min 4s
# <timed exec>:38: RuntimeWarning: Mean of empty slice.
# c:\Users\Owner\pyenvs\dev39\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
score_list
# Out:
# []

# %% [markdown]
# Cross-validation shows us the average correlation between predictions and ground truth. The histogram additionally shows how the correlations of the cells are distributed. While most correlations are around 0.9, there exist a few predictions with negative correlations.

# %%
# corr_list = []
# for i in range(len(y_va)):
#     corr_list.append(np.corrcoef(y_va[i], y_va_pred[i])[1, 0])
# plt.figure(figsize=(10, 4))
# plt.hist(corr_list, bins=100, density=True, color='lightgreen')
# plt.title('Distribution of correlations')
# plt.xlabel('Correlation')
# plt.ylabel('Density')
# plt.show()

# %% [markdown]
# # Prediction and submission
#
# We ensemble the test predictions of all Keras models.
#
# It has been pointed out in several discussion posts that the first 7476 rows of test (day 2, donor 27678) are identical to the first 7476 rows of train (day 2, donor 32606):
# - [CITEseq data: same RNA expression matrices from different donors in day2?](https://www.kaggle.com/competitions/open-problems-multimodal/discussion/349867) (@gwentea)
# -[Data contamination between CITEseq train/test datasets?](https://www.kaggle.com/competitions/open-problems-multimodal/discussion/349833) (@aglaros)
# - [Leak in public test set](https://www.kaggle.com/competitions/open-problems-multimodal/discussion/349867) (@psilogram)
#
# These rows belong to the public test set; the private leaderboard is not affected. We copy the 7476 rows from the training targets into the test predictions.
#
# At the end we concatenate the CITEseq predictions with @jsmithperera's predictions of the [Multiome Quickstart w/ Sparse M + tSVD = 32](https://www.kaggle.com/code/jsmithperera/multiome-quickstart-w-sparse-m-tsvd-32) notebook to get a complete submission.

# %%
if SUBMIT:
    test_pred = np.zeros((len(Xt), 140), dtype=np.float32)
    for fold in range(N_SPLITS):
        print(f"Predicting with fold {fold}")
        with open(f'model{fold:02}.pkl', 'rb') as file:
            model = pickle.load(file)
        test_pred += model.predict(Xt)
    
    # Copy the targets for the data leak
    test_pred[:7476] = Y[:7476]

    #with open("../input/msci-multiome-quickstart/partial_submission_multi.pickle", 'rb') as f: submission = pickle.load(f)
    submission = pd.read_csv('C:/Users/Owner/Documents/dev/open-problem/Multiome-w-Sparse-M-tSVD-32/submission.csv',
                             index_col='row_id', squeeze=True)
    submission.iloc[:len(test_pred.ravel())] = test_pred.ravel()
    assert not submission.isna().any()
    submission.to_csv(submission_name)
    display(submission)
# Out:
# Predicting with fold 0
# Predicting with fold 1
# Predicting with fold 2
# Predicting with fold 3
# Predicting with fold 4
# row_id
# 0           0.094605
# 1          -0.162362
# 2          -0.405332
# 3          -0.302582
# 4           1.114355
#               ...
# 65744175    6.206671
# 65744176    0.045758
# 65744177    0.032102
# 65744178    1.350810
# 65744179    5.112195
# Name: target, Length: 65744180, dtype: float64
